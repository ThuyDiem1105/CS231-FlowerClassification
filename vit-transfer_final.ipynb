# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/flowerdatasets/flowers/val/orchid/5479838376_b9ef4b2dd4_k.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/15317253397_c17cf35524_o.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/2068689248_2f31a3160b_k.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/15368996319_9f8354726f_k.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/8505987237_cf07748498_c.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/6467770439_cf417e8003_k.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/2452354536_2e0380c81e_c.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/6803947634_f0ed5fec65_k.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/6921280358_c7a94654e2_o.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/57715059_fc26450350_o.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/12241437214_05d3b7a7eb_o.jpg
# /kaggle/input/flowerdatasets/flowers/val/orchid/2187054004_ca79f859e6_o.jpg
# ...

# %%
# !pip install transformers

# %%
# =================================================================
# IMPORTS & SEED SETUP
# =================================================================
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import os
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from tqdm import tqdm
from transformers import TFViTModel
import random

# ===== FIX ALL RANDOM SEEDS =====
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suppress TF warnings
tf.config.experimental.enable_op_determinism()
print(f"🔒 All random seeds fixed to {SEED}")

# =================================================================
# 1. CẤU HÌNH THAM SỐ
# =================================================================
IMG_HEIGHT = 224
IMG_WIDTH = 224
INPUT_SHAPE = (IMG_HEIGHT, IMG_WIDTH, 3)
NUM_CLASSES = 7

BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 0.001

PRETRAINED_MODEL = "google/vit-base-patch16-224"

vit_weights_path = '/kaggle/working/vit_transfer_model.weights.h5'
plot_history_path = '/kaggle/working/training_curves.png'

print("="*70)
print("VIT TRANSFER LEARNING (PRE-TRAINED) + SVM CLASSIFIER")
print("="*70)
print(f"Using pre-trained model: {PRETRAINED_MODEL}")
print("="*70)
# =================================================================
# 2. ĐỊNH NGHĨA LỚP BỌC (KHẮC PHỤC LỖI KERASTENSOR VÀ CHANNEL ORDERING)
# =================================================================
class ViTFeatureExtractorLayer(tf.keras.layers.Layer):
    """Gói TFViTModel vào lớp Keras Subclass để xử lý KerasTensor và gọi hàm."""
    def __init__(self, model_name, **kwargs):
        super().__init__(**kwargs)
        self.vit_model = TFViTModel.from_pretrained(
            model_name,
            output_hidden_states=True, 
            output_attentions=False
        )
    def call(self, inputs):
        outputs = self.vit_model(pixel_values=inputs, training=False)
        return outputs.pooler_output

# =================================================================
# 3. ĐỊNH NGHĨA DATA PIPELINE & AUGMENTATION
# =================================================================
def load_and_preprocess_image(filepath, label):
    image = tf.io.read_file(filepath)
    image = tf.image.decode_image(image, channels=3, expand_animations=False)
    image.set_shape([None, None, 3])
    image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# =================================================================
# 4. XÂY DỰNG MODEL VỚI PRE-TRAINED VIT
# =================================================================
def build_vit_transfer_learning(num_classes=NUM_CLASSES, trainable_layers='all'):
    
    vit_feature_layer = ViTFeatureExtractorLayer(model_name='google/vit-base-patch16-224')
    vit_base = vit_feature_layer.vit_model

    if trainable_layers == 'head':
        vit_base.trainable = False
    elif trainable_layers == 'all':
        vit_base.trainable = True
    elif isinstance(trainable_layers, int):
        vit_base.trainable = True
        for layer in vit_base.layers[:-trainable_layers]:
            layer.trainable = False
    
    inputs = layers.Input(shape=INPUT_SHAPE, name='pixel_values')
    
    x = layers.Normalization(
        mean=[0.5, 0.5, 0.5],
        variance=[0.25, 0.25, 0.25]
    )(inputs)

    # KHẮC PHỤC LỖI CHANNEL ORDERING: (N, H, W, C) -> (N, C, H, W)
    x = layers.Permute((3, 1, 2))(x)
    
    features = vit_feature_layer(x)
    
    features = layers.Dense(256, activation="gelu", name="feature_dense_1")(features)
    features = layers.Dropout(0.5, name="feature_dropout_1")(features)
    features = layers.Dense(128, activation="gelu", name="feature_dense_2")(features)
    features = layers.Dropout(0.4, name="feature_dropout_2")(features)
    
    outputs = layers.Dense(num_classes, activation="softmax", name="predictions")(features)
    
    full_model = tf.keras.Model(inputs=inputs, outputs=outputs, name="ViT_Transfer_Full")
    
    feature_extractor = tf.keras.Model(
        inputs=inputs,
        outputs=full_model.get_layer("feature_dense_2").output,
        name="ViT_Transfer_FeatureExtractor"
    )
    
    return full_model, feature_extractor, vit_base
# =================================================================
# 5. LOAD DỮ LIỆU
# =================================================================
def load_image_paths_labels(data_dir):
    class_names = sorted(os.listdir(data_dir))
    paths = []
    labels = []
    for i, cls in enumerate(class_names):
        cls_dir = os.path.join(data_dir, cls)
        if not os.path.isdir(cls_dir):
            continue
        for fname in os.listdir(cls_dir):
            if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                paths.append(os.path.join(cls_dir, fname))
                labels.append(i)
    return paths, labels, class_names

train_dir = '/kaggle/input/flowerdatasets/flowers/train'
val_dir = '/kaggle/input/flowerdatasets/flowers/val'
test_dir = '/kaggle/input/flowerdatasets/flowers/test'

train_paths, train_labels, class_names = load_image_paths_labels(train_dir)
val_paths, val_labels, _ = load_image_paths_labels(val_dir)
test_paths, test_labels, _ = load_image_paths_labels(test_dir)

print(f"\nClasses: {class_names}")
print(f"Train samples: {len(train_paths)}")
print(f"Validation samples: {len(val_paths)}")
print(f"Test samples: {len(test_paths)}")

train_labels_one_hot = tf.keras.utils.to_categorical(train_labels, num_classes=NUM_CLASSES)
val_labels_one_hot = tf.keras.utils.to_categorical(val_labels, num_classes=NUM_CLASSES)
test_labels_one_hot = tf.keras.utils.to_categorical(test_labels, num_classes=NUM_CLASSES)

# =================================================================
# 6. TẠO DATA PIPELINE
# =================================================================
train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels_one_hot))
train_ds = train_ds.shuffle(len(train_paths)) \
    .map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE) \
    .map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val_paths, val_labels_one_hot))
val_ds = val_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((test_paths, test_labels_one_hot))
test_ds = test_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

# =================================================================
# 7. TRAINING VIT (HEAD-ONLY)
# =================================================================
print("\n" + "="*70)
print("BƯỚC 1: TRAINING HEAD CỦA VIT TRANSFER LEARNING MODEL (HEAD-ONLY)")
print("="*70)

# CẤU HÌNH HEAD-ONLY
RETRAIN_VIT = True
FINE_TUNE_VIT = False
TRAINABLE_LAYERS = 'head'

full_model, feature_extractor, vit_base = build_vit_transfer_learning(
    num_classes=NUM_CLASSES,
    trainable_layers=TRAINABLE_LAYERS
)

# Đặt lại trạng thái FREEZE
vit_base.trainable = False 
print("📌 Backbone ViT đã bị đóng băng (Frozen). Chỉ huấn luyện Classifier Head.")
print(f"  - Total params: {full_model.count_params():,}")
print(f"  - Trainable params: {sum([tf.size(w).numpy() for w in full_model.trainable_weights]):,}")

# --- HÀM VẼ BIỂU ĐỒ MỚI ---
def plot_training_history(history, filename):
    plt.figure(figsize=(15, 5))

    # Loss plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Accuracy plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.show()

if RETRAIN_VIT:
    print("\n🔄 Training Classifier Head (Frozen Backbone)...")
    
    full_model.compile(
        optimizer=tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=10,
            restore_best_weights=True,
            verbose=1
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=5,
            min_lr=1e-7,
            verbose=1
        ),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=vit_weights_path,
            monitor='val_accuracy',
            save_best_only=True,
            save_weights_only=True,
            verbose=1
        )
    ]
    
    history = full_model.fit(
        train_ds,
        epochs=EPOCHS,
        validation_data=val_ds,
        callbacks=callbacks,
        verbose=1
    )
    
    print("✓ Training Head hoàn tất!")
    # VẼ BIỂU ĐỒ SAU KHI TRAIN
    plot_training_history(history, plot_history_path)

else:
    print("\n📁 OPTION 3: Load weights có sẵn...")
    if os.path.exists(vit_weights_path):
        full_model.load_weights(vit_weights_path)
        print("✓ Load weights thành công!")
    else:
        print("❌ KHÔNG tìm thấy weights!")
        raise FileNotFoundError(f"Weights file not found: {vit_weights_path}")

print("\n📊 Đánh giá ViT Transfer Learning trên test set:")
full_model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
test_loss, test_acc = full_model.evaluate(test_ds, verbose=0)
print(f"ViT Transfer Learning Test Accuracy: {test_acc * 100:.2f}%")

# =================================================================
# 8. TRÍCH XUẤT FEATURES VỚI VIT
# =================================================================
print("\n" + "="*70)
print("BƯỚC 2: TRÍCH XUẤT FEATURES TỪ VIT")
print("="*70)

def extract_features_vit(model, image_paths, batch_size=32):
    features_list = []
    
    def load_image_only(filepath):
        image = tf.io.read_file(filepath)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
        image = tf.cast(image, tf.float32) / 255.0
        return image
    
    ds = tf.data.Dataset.from_tensor_slices(image_paths)
    ds = ds.map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE) \
        .batch(batch_size) \
        .prefetch(tf.data.AUTOTUNE)
    
    for batch in tqdm(ds, desc="Extracting features"):
        batch_features = model(batch, training=False).numpy()
        features_list.append(batch_features)
    
    features = np.concatenate(features_list, axis=0)
    return features

print("\nTrích xuất features cho tập train...")
train_features = extract_features_vit(feature_extractor, train_paths)

print("\nTrích xuất features cho tập validation...")
val_features = extract_features_vit(feature_extractor, val_paths)

print("\nTrích xuất features cho tập test...")
test_features = extract_features_vit(feature_extractor, test_paths)

print(f"\n✓ Kích thước features:")
print(f"  Train: {train_features.shape}")
print(f"  Val: {val_features.shape}")
print(f"  Test: {test_features.shape}")

# =================================================================
# 9. CHUẨN HÓA FEATURES
# =================================================================
print("\n" + "="*70)
print("BƯỚC 3: CHUẨN HÓA FEATURES")
print("="*70)

scaler = StandardScaler()
train_features_scaled = scaler.fit_transform(train_features)
val_features_scaled = scaler.transform(val_features)
test_features_scaled = scaler.transform(test_features)

print("✓ Đã chuẩn hóa features với StandardScaler")

# =================================================================
# 10. TRAINING SVM VỚI HYPERPARAMETERS CỐ ĐỊNH
# =================================================================
print("\n" + "="*70)
print("BƯỚC 4: TRAINING SVM CLASSIFIER")
print("="*70)

# Cấu hình hyperparameters cố định
SVM_CONFIG = {
    'C': 10,
    'gamma': 'scale',
    'kernel': 'rbf',
    'random_state': 42
}

print(f"\n📋 SVM Hyperparameters (Fixed):")
print("-" * 70)
for key, value in SVM_CONFIG.items():
    print(f"  {key:<15} : {value}")
print("-" * 70)

print("\n🔄 Training SVM với hyperparameters cố định...")
svm_classifier = SVC(**SVM_CONFIG)
svm_classifier.fit(train_features_scaled, train_labels)
print("✓ Training hoàn tất!")

# Đánh giá trên validation set
val_pred_svm = svm_classifier.predict(val_features_scaled)
val_acc_svm = accuracy_score(val_labels, val_pred_svm)
val_f1_svm = f1_score(val_labels, val_pred_svm, average='macro')

print(f"\n📊 Validation Performance:")
print("-" * 70)
print(f"Validation Accuracy: {val_acc_svm * 100:.2f}%")
print(f"Validation F1-Score (Macro): {val_f1_svm * 100:.2f}%")
print("-" * 70)

# =================================================================
# 11. ĐÁNH GIÁ SVM
# =================================================================
print("\n" + "="*70)
print("BƯỚC 5: ĐÁNH GIÁ HIỆU SUẤT")
print("="*70)

test_pred_svm = svm_classifier.predict(test_features_scaled)
test_acc_svm = accuracy_score(test_labels, test_pred_svm)
test_f1_svm = f1_score(test_labels, test_pred_svm, average='macro')

print("\n" + "-"*70)
print("SO SÁNH KẾT QUẢ")
print("-"*70)
print(f"{'Model':<35} {'Test Accuracy':<15}")
print("-"*70)
print(f"{'ViT Transfer + Softmax':<35} {test_acc*100:>6.2f}%")
print(f"{'ViT Transfer + SVM':<35} {test_acc_svm*100:>6.2f}%")
print("-"*70)

# =================================================================
# 12. CLASSIFICATION REPORT VÀ CONFUSION MATRIX
# =================================================================
print("\n" + "="*70)
print("CHI TIẾT PHÂN TÍCH - VIT TRANSFER + SVM")
print("="*70)

print("\nClassification Report:")
print("-"*70)
print(classification_report(test_labels, test_pred_svm, target_names=class_names, digits=4))

def plot_confusion_matrix(y_true, y_pred, title, filename):
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names,
                cbar_kws={'label': 'Count'})
    plt.title(title, fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
    plt.ylabel('True Label', fontsize=12, fontweight='bold')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.show()

plot_confusion_matrix(
    test_labels,
    test_pred_svm,
    'Confusion Matrix - ViT Transfer Learning + SVM',
    '/kaggle/working/confusion_matrix_vit_transfer_svm.png'
)

# =================================================================
# THÊM PHẦN NÀY: PHÂN TÍCH VIT + SOFTMAX
# =================================================================
print("\n" + "="*70)
print("CHI TIẾT PHÂN TÍCH - VIT TRANSFER + SOFTMAX")
print("="*70)

# Lấy predictions từ ViT + Softmax
test_pred_softmax = []
test_true_labels = []

for images, labels in test_ds:
    preds = full_model.predict(images, verbose=0)
    test_pred_softmax.extend(np.argmax(preds, axis=1))
    test_true_labels.extend(np.argmax(labels.numpy(), axis=1))

test_pred_softmax = np.array(test_pred_softmax)
test_true_labels = np.array(test_true_labels)

print("\nClassification Report:")
print("-"*70)
print(classification_report(test_true_labels, test_pred_softmax, 
                           target_names=class_names, digits=4))

# Vẽ Confusion Matrix cho Softmax
plot_confusion_matrix(
    test_true_labels,
    test_pred_softmax,
    'Confusion Matrix - ViT Transfer Learning + Softmax',
    '/kaggle/working/confusion_matrix_vit_transfer_softmax.png'
)

# =================================================================
# SO SÁNH TỔNG QUÁT GIỮA 2 PHƯƠNG PHÁP
# =================================================================
print("\n" + "="*70)
print("SO SÁNH TỔNG QUÁT: SOFTMAX vs SVM")
print("="*70)

acc_softmax = accuracy_score(test_true_labels, test_pred_softmax)
f1_softmax = f1_score(test_true_labels, test_pred_softmax, average='macro')

print(f"\n{'Metric':<25} {'ViT + Softmax':<20} {'ViT + SVM':<20}")
print("-"*70)
print(f"{'Test Accuracy':<25} {acc_softmax*100:>6.2f}%{' '*13} {test_acc_svm*100:>6.2f}%")
print(f"{'Macro F1-Score':<25} {f1_softmax*100:>6.2f}%{' '*13} {test_f1_svm*100:>6.2f}%")
print("-"*70)

# So sánh số lượng lỗi
errors_softmax = np.sum(test_true_labels != test_pred_softmax)
errors_svm = np.sum(test_labels != test_pred_svm)
print(f"{'Total Errors':<25} {errors_softmax:>6}/{len(test_true_labels):<13} {errors_svm:>6}/{len(test_labels)}")

# So sánh chi tiết từng class - FIXED VERSION
print(f"\n{'Class-wise Errors:':<25}")
print("-"*70)
print(f"{'Class':<15} {'Softmax Errors':<20} {'SVM Errors':<20}")
print("-"*70)

for i, class_name in enumerate(class_names):
    # Softmax: Dùng test_true_labels
    mask_softmax = test_true_labels == i
    errors_soft_class = np.sum(test_pred_softmax[mask_softmax] != i)
    total_soft_class = np.sum(mask_softmax)
    
    # SVM: Dùng test_labels
    mask_svm = test_labels == i
    errors_svm_class = np.sum(test_pred_svm[mask_svm] != i)
    total_svm_class = np.sum(mask_svm)
    
    print(f"{class_name:<15} {errors_soft_class:>6}/{total_soft_class:<13} {errors_svm_class:>6}/{total_svm_class}")

print("="*70)

# Phân tích sự khác biệt
diff_predictions = np.sum(test_pred_softmax != test_pred_svm)
print(f"\n📊 Sự khác biệt giữa 2 classifiers:")
print(f"   - Số mẫu có dự đoán KHÁC NHAU: {diff_predictions}/{len(test_true_labels)} ({diff_predictions/len(test_true_labels)*100:.2f}%)")

if diff_predictions > 0:
    # Tìm những mẫu mà 2 classifier dự đoán khác nhau
    diff_indices = np.where(test_pred_softmax != test_pred_svm)[0]
    
    # Phân loại: cả 2 đều sai, 1 đúng 1 sai, hoặc cả 2 đúng nhưng khác nhau
    both_wrong = np.sum((test_pred_softmax[diff_indices] != test_true_labels[diff_indices]) & 
                        (test_pred_svm[diff_indices] != test_labels[diff_indices]))
    softmax_correct = np.sum((test_pred_softmax[diff_indices] == test_true_labels[diff_indices]) & 
                             (test_pred_svm[diff_indices] != test_labels[diff_indices]))
    svm_correct = np.sum((test_pred_softmax[diff_indices] != test_true_labels[diff_indices]) & 
                         (test_pred_svm[diff_indices] == test_labels[diff_indices]))
    
    print(f"\n   Trong đó:")
    print(f"   - Cả 2 đều SAI:        {both_wrong}")
    print(f"   - Chỉ Softmax ĐÚNG:    {softmax_correct}")
    print(f"   - Chỉ SVM ĐÚNG:        {svm_correct}")
    
    # Hiển thị chi tiết những mẫu khác nhau
    if diff_predictions <= 10:  # Nếu số lượng ít, hiển thị chi tiết
        print(f"\n   Chi tiết từng mẫu khác biệt:")
        print(f"   {'Index':<8} {'True':<12} {'Softmax':<12} {'SVM':<12}")
        print(f"   {'-'*50}")
        for idx in diff_indices:
            print(f"   {idx:<8} {class_names[test_true_labels[idx]]:<12} {class_names[test_pred_softmax[idx]]:<12} {class_names[test_pred_svm[idx]]:<12}")
else:
    print("   ✅ Cả 2 classifiers cho kết quả GIỐNG HỆT NHAU!")

print("="*70)
# =================================================================
# 13. HIỂN THỊ ẢNH DỰ ĐOÁN ĐÚNG VÀ SAI
# =================================================================
print("\n" + "="*70)
print("PHÂN TÍCH DỰ ĐOÁN ĐÚNG VÀ SAI")
print("="*70)

def plot_predictions(image_paths, true_labels, pred_labels, class_names,
                     indices, title, filename, correct=True):
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    fig.suptitle(title, fontsize=16, fontweight='bold', y=1.02)
    
    for idx, ax in zip(indices, axes):
        img = tf.keras.preprocessing.image.load_img(image_paths[idx])
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        
        ax.imshow(img_array.astype('uint8'))
        ax.axis('off')
        
        true_class = class_names[true_labels[idx]]
        pred_class = class_names[pred_labels[idx]]
        
        color = 'green' if correct else 'red'
        symbol = '✓' if correct else '✗'
        
        ax.set_title(
            f'{symbol} Prediction: {pred_class}\nTrue: {true_class}',
            fontsize=11,
            fontweight='bold',
            color=color,
            pad=10
        )
    
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.show()

correct_indices = np.where(test_pred_svm == test_labels)[0]
incorrect_indices = np.where(test_pred_svm != test_labels)[0]

print(f"\n📊 Thống kê:")
print(f"  - Số ảnh dự đoán ĐÚNG: {len(correct_indices)}/{len(test_labels)} ({len(correct_indices)/len(test_labels)*100:.2f}%)")
print(f"  - Số ảnh dự đoán SAI: {len(incorrect_indices)}/{len(test_labels)} ({len(incorrect_indices)/len(test_labels)*100:.2f}%)")

if len(correct_indices) >= 3:
    correct_samples = np.random.choice(correct_indices, 3, replace=False)
    
    print("\n🎯 Hiển thị 3 ảnh dự đoán ĐÚNG:")
    plot_predictions(
        test_paths, test_labels, test_pred_svm, class_names,
        correct_samples,
        '✓ DỰ ĐOÁN ĐÚNG - SVM PREDICTIONS',
        '/kaggle/working/correct_predictions.png',
        correct=True
    )
else:
    print("\n⚠️ Không đủ 3 ảnh dự đoán đúng để hiển thị")

if len(incorrect_indices) >= 3:
    incorrect_samples = np.random.choice(incorrect_indices, 3, replace=False)
    
    print("\n❌ Hiển thị 3 ảnh dự đoán SAI:")
    plot_predictions(
        test_paths, test_labels, test_pred_svm, class_names,
        incorrect_samples,
        '✗ DỰ ĐOÁN SAI - SVM PREDICTIONS',
        '/kaggle/working/incorrect_predictions.png',
        correct=False
    )
else:
    print("\n✓ Model hoàn hảo! Không có ảnh dự đoán sai")


# =================================================================
# 14. LƯU MÔ HÌNH - SAVEDMODEL FORMAT (FOLDER)
# =================================================================
print("\n" + "="*70)
print("LƯU MÔ HÌNH - SAVEDMODEL FORMAT")
print("="*70)

# QUAN TRỌNG: Compile model trước khi lưu
full_model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Lưu TOÀN BỘ model với SavedModel format (FOLDER, không phải .keras file)
print("💾 Saving complete model...")
try:
    full_model.save('/kaggle/working/vit_flower_model')
    print("✓ Đã lưu: vit_flower_model/ (SavedModel format)")
except Exception as e:
    print(f"❌ Lỗi khi lưu: {e}")
    print("\n🔧 Thử phương án dự phòng: Export inference-only model...")
    
    # Tạo inference model (không có training components)
    @tf.function(input_signature=[tf.TensorSpec(shape=[None, IMG_HEIGHT, IMG_WIDTH, 3], dtype=tf.float32)])
    def serving_fn(images):
        return full_model(images, training=False)
    
    # Save với concrete function
    tf.saved_model.save(
        full_model,
        '/kaggle/working/vit_flower_model',
        signatures={'serving_default': serving_fn}
    )
    print("✓ Đã lưu: vit_flower_model/ (Inference-only)")

# Lưu metadata
model_metadata = {
    'class_names': class_names,
    'img_size': (IMG_HEIGHT, IMG_WIDTH),
    'test_accuracy': test_acc,
    'pretrained_model': PRETRAINED_MODEL,
    'num_classes': NUM_CLASSES
}

with open('/kaggle/working/model_metadata.pkl', 'wb') as f:
    pickle.dump(model_metadata, f)
print("✓ Đã lưu: model_metadata.pkl")

# Check folder size
from pathlib import Path
folder_size = sum(f.stat().st_size for f in Path('/kaggle/working/vit_flower_model').rglob('*')) / (1024*1024)
print(f"\n📊 Model info:")
print(f"  - Folder size: {folder_size:.1f} MB")
print(f"  - Test Accuracy: {test_acc * 100:.2f}%")

if folder_size < 100:
    print("\n⚠️ WARNING: Folder size quá nhỏ! ViT weights có thể chưa được lưu!")
else:
    print("✅ Folder size hợp lý - ViT weights đã được lưu!")

# =================================================================
# 15. TEST LOAD VÀ DỰ ĐOÁN
# =================================================================
print("\n" + "="*70)
print("DEMO: LOAD VÀ DỰ ĐOÁN")
print("="*70)

# Load metadata
with open('/kaggle/working/model_metadata.pkl', 'rb') as f:
    metadata = pickle.load(f)

print(f"✓ Loaded metadata")
print(f"  - Classes: {metadata['class_names']}")
print(f"  - Test Accuracy: {metadata['test_accuracy']*100:.2f}%")

# Load model
print("\n📂 Loading model...")
is_savedmodel_format = False
try:
    # Thử load với custom_objects
    loaded_model = tf.keras.models.load_model(
        '/kaggle/working/vit_flower_model',
        custom_objects={'ViTFeatureExtractorLayer': ViTFeatureExtractorLayer}
    )
    print("✓ Model loaded successfully!")
except Exception as e:
    print(f"⚠️ Không load được với keras API: {e}")
    print("🔧 Thử load với SavedModel API...")
    
    # Load với SavedModel API
    loaded_model = tf.saved_model.load('/kaggle/working/vit_flower_model')
    is_savedmodel_format = True
    print("✓ Model loaded với SavedModel API!")
    print("⚠️ Note: Chỉ có thể dùng inference, không train được")
    
    # Kiểm tra signatures
    print(f"📋 Available signatures: {list(loaded_model.signatures.keys())}")

# =================================================================
# 16. TEST DỰ ĐOÁN VÀ SO SÁNH
# =================================================================
print("\n" + "="*70)
print("TEST DỰ ĐOÁN")
print("="*70)

def predict_image(image_path, model, class_names, is_savedmodel=False):
    """Dự đoán class cho 1 ảnh"""
    image = tf.io.read_file(image_path)
    image = tf.image.decode_image(image, channels=3, expand_animations=False)
    image.set_shape([None, None, 3])
    image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.expand_dims(image, 0)
    
    if is_savedmodel:
        # Dùng SavedModel signature
        infer = model.signatures['serving_default']
        predictions = infer(image)
        # Output có thể là dict, cần extract tensor
        if isinstance(predictions, dict):
            predictions = list(predictions.values())[0].numpy()
        else:
            predictions = predictions.numpy()
    else:
        # Keras API
        predictions = model.predict(image, verbose=0)
    
    pred_class = np.argmax(predictions[0])
    confidence = predictions[0][pred_class]
    
    return pred_class, confidence

# Test trên 10 ảnh ngẫu nhiên
test_sample_size = min(10, len(test_paths))
sample_indices = np.random.choice(len(test_paths), test_sample_size, replace=False)

print(f"\n🔮 So sánh dự đoán giữa ORIGINAL model và LOADED model:")
print("-"*80)
print(f"{'True Class':<15} {'Original':<15} {'Conf':<8} {'Loaded':<15} {'Conf':<8} {'Match':<10}")
print("-"*80)

correct_original = 0
correct_loaded = 0
predictions_match = 0

for idx in sample_indices:
    path = test_paths[idx]
    true_class = test_labels[idx]
    
    # Predict với original model
    pred_orig, conf_orig = predict_image(path, full_model, class_names, is_savedmodel=False)
    
    # Predict với loaded model
    pred_load, conf_load = predict_image(path, loaded_model, metadata['class_names'], is_savedmodel=is_savedmodel_format)
    
    # Check accuracy
    if pred_orig == true_class:
        correct_original += 1
    if pred_load == true_class:
        correct_loaded += 1
    
    # Check if predictions match
    match = "✓" if pred_orig == pred_load else "✗"
    if pred_orig == pred_load:
        predictions_match += 1
    
    print(f"{class_names[true_class]:<15} {class_names[pred_orig]:<15} {conf_orig*100:>5.1f}% {' '*2} "
          f"{metadata['class_names'][pred_load]:<15} {conf_load*100:>5.1f}% {' '*2} {match}")

print("-"*80)
print(f"Original Model Accuracy: {correct_original}/{test_sample_size} ({correct_original/test_sample_size*100:.1f}%)")
print(f"Loaded Model Accuracy:   {correct_loaded}/{test_sample_size} ({correct_loaded/test_sample_size*100:.1f}%)")
print(f"Predictions Match:       {predictions_match}/{test_sample_size} ({predictions_match/test_sample_size*100:.1f}%)")

if predictions_match == test_sample_size:
    print("\n✅ PERFECT: Original và Loaded model cho kết quả GIỐNG HỆT NHAU!")
elif correct_loaded >= test_sample_size * 0.95:
    print(f"\n✅ GOOD: Loaded model hoạt động tốt ({correct_loaded/test_sample_size*100:.1f}% accuracy)")
else:
    print(f"\n❌ ERROR: Loaded model có vấn đề nghiêm trọng!")

# =================================================================
# 17. VERIFY TRÊN TOÀN BỘ TEST SET
# =================================================================
print("\n" + "="*70)
print("VERIFY TRÊN TOÀN BỘ TEST SET")
print("="*70)

print("\n🔄 Evaluating original model...")
test_loss_orig, test_acc_orig = full_model.evaluate(test_ds, verbose=0)

print("🔄 Evaluating loaded model...")
if is_savedmodel_format:
    print("⚠️ SavedModel format - dự đoán từng batch...")
    correct = 0
    total = 0
    infer = loaded_model.signatures['serving_default']
    for images, labels in test_ds:
        preds = infer(images)
        # Extract predictions from dict or tensor
        if isinstance(preds, dict):
            preds = list(preds.values())[0].numpy()
        else:
            preds = preds.numpy()
        pred_classes = np.argmax(preds, axis=1)
        true_classes = np.argmax(labels.numpy(), axis=1)
        correct += np.sum(pred_classes == true_classes)
        total += len(true_classes)
    test_acc_load = correct / total
    test_loss_load = 0.0
else:
    test_loss_load, test_acc_load = loaded_model.evaluate(test_ds, verbose=0)

print("\n📊 RESULTS:")
print("-"*70)
print(f"Original Model: Loss = {test_loss_orig:.4f}, Accuracy = {test_acc_orig*100:.2f}%")
print(f"Loaded Model:   Loss = {test_loss_load:.4f}, Accuracy = {test_acc_load*100:.2f}%")
print(f"Difference:     Accuracy = {abs(test_acc_orig - test_acc_load)*100:.4f}%")
print("-"*70)

if abs(test_acc_orig - test_acc_load) < 0.01:
    print("✅ PERFECT: Model được load chính xác!")
elif test_acc_load > 0.95:
    print("✅ GOOD: Model hoạt động tốt!")
else:
    print("❌ ERROR: Có vấn đề khi load model!")
# Out:
# 2025-12-01 12:13:13.351410: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764591193.841732      20 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764591193.986785      20 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# ...

# %%
# =================================================================
# 18. PHÂN TÍCH IMAGES DỰ ĐOÁN SAI (CHI TIẾT HƠN)
# =================================================================
print("\n" + "="*70)
print("PHÂN TÍCH CHI TIẾT ẢNH DỰ ĐOÁN SAI")
print("="*70)

# Tìm tất cả ảnh sai
incorrect_indices = np.where(test_pred_svm != test_labels)[0]

if len(incorrect_indices) > 0:
    print(f"\n❌ Tìm thấy {len(incorrect_indices)} ảnh dự đoán SAI:")
    print("-"*70)
    
    for i, idx in enumerate(incorrect_indices[:10], 1):  # Chỉ show 10 ảnh đầu
        true_class = class_names[test_labels[idx]]
        pred_class = class_names[test_pred_svm[idx]]
        
        # Load ảnh
        img = tf.keras.preprocessing.image.load_img(test_paths[idx])
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        
        # Predict để lấy confidence
        img_preprocessed = tf.image.resize(img_array, [IMG_HEIGHT, IMG_WIDTH])
        img_preprocessed = tf.cast(img_preprocessed, tf.float32) / 255.0
        img_preprocessed = tf.expand_dims(img_preprocessed, 0)
        
        predictions = full_model.predict(img_preprocessed, verbose=0)
        pred_confidence = predictions[0][test_pred_svm[idx]]
        true_confidence = predictions[0][test_labels[idx]]
        
        print(f"{i}. File: {os.path.basename(test_paths[idx])}")
        print(f"   True: {true_class} (confidence: {true_confidence*100:.2f}%)")
        print(f"   Pred: {pred_class} (confidence: {pred_confidence*100:.2f}%)")
        print(f"   Difference: {abs(pred_confidence - true_confidence)*100:.2f}%")
        print("-"*70)
    
    # Vẽ grid ảnh sai
    num_errors = min(9, len(incorrect_indices))
    fig, axes = plt.subplots(3, 3, figsize=(15, 15))
    fig.suptitle('❌ IMAGES DỰ ĐOÁN SAI', fontsize=18, fontweight='bold', y=0.995)
    
    for i, idx in enumerate(incorrect_indices[:num_errors]):
        ax = axes[i // 3, i % 3]
        
        img = tf.keras.preprocessing.image.load_img(test_paths[idx])
        ax.imshow(img)
        ax.axis('off')
        
        true_class = class_names[test_labels[idx]]
        pred_class = class_names[test_pred_svm[idx]]
        
        ax.set_title(
            f'True: {true_class}\nPred: {pred_class}',
            fontsize=10,
            fontweight='bold',
            color='red'
        )
    
    # Ẩn axes thừa
    for i in range(num_errors, 9):
        axes[i // 3, i % 3].axis('off')
    
    plt.tight_layout()
    plt.savefig('/kaggle/working/all_incorrect_predictions.png', dpi=300, bbox_inches='tight')
    plt.show()
    
else:
    print("\n✅ HOÀN HẢO! Không có ảnh nào dự đoán sai!")

# =================================================================
# 19. MODEL SUMMARY & ARCHITECTURE
# =================================================================
print("\n" + "="*70)
print("MODEL SUMMARY & ARCHITECTURE")
print("="*70)

print("\n📋 FULL MODEL SUMMARY:")
print("-"*70)
full_model.summary()

print("\n📋 FEATURE EXTRACTOR SUMMARY:")
print("-"*70)
feature_extractor.summary()

# Lưu summary vào file
with open('/kaggle/working/model_summary.txt', 'w') as f:
    full_model.summary(print_fn=lambda x: f.write(x + '\n'))
print("\n✓ Đã lưu: model_summary.txt")

# =================================================================
# 20. VIT ARCHITECTURE DIAGRAM
# =================================================================
print("\n" + "="*70)
print("VIT ARCHITECTURE VISUALIZATION")
print("="*70)

def plot_vit_architecture():
    """Vẽ diagram kiến trúc ViT"""
    fig, ax = plt.subplots(figsize=(14, 10))
    ax.set_xlim(0, 10)
    ax.set_ylim(0, 12)
    ax.axis('off')
    
    # Title
    ax.text(5, 11.5, 'Vision Transformer (ViT) Architecture', 
            ha='center', fontsize=18, fontweight='bold')
    
    # Components
    components = [
        # (x, y, width, height, text, color)
        (2, 10, 6, 0.8, 'Input Image (224×224×3)', '#E8F4F8'),
        (2, 8.8, 6, 0.8, 'Patch Embedding\n(16×16 patches → 196 patches)', '#B8E6F0'),
        (2, 7.6, 6, 0.8, 'Add Position Embedding (768-dim)', '#88D8E8'),
        (2, 6.4, 6, 0.8, 'Transformer Encoder (×12 layers)', '#58CAE0'),
        (3.5, 5.2, 3, 0.5, 'Multi-Head Self-Attention', '#48BAD0'),
        (3.5, 4.5, 3, 0.5, 'Layer Normalization', '#38AAC0'),
        (3.5, 3.8, 3, 0.5, 'MLP (Feed-Forward)', '#2898B0'),
        (3.5, 3.1, 3, 0.5, 'Layer Normalization', '#38AAC0'),
        (2, 2, 6, 0.8, '[CLS] Token Output (768-dim)', '#88D8E8'),
        (2, 0.8, 6, 0.8, 'Classification Head (Frozen Backbone)', '#FFE5B4'),
        (3, -0.2, 4, 0.5, 'Dense (256) + Dropout (0.5)', '#FFD494'),
        (3, -0.8, 4, 0.5, 'Dense (128) + Dropout (0.4)', '#FFC374'),
        (3, -1.4, 4, 0.5, 'Output (7 classes)', '#FFB254'),
    ]
    
    for x, y, w, h, text, color in components:
        # Draw box
        rect = plt.Rectangle((x, y), w, h, facecolor=color, 
                            edgecolor='black', linewidth=2)
        ax.add_patch(rect)
        # Add text
        ax.text(x + w/2, y + h/2, text, ha='center', va='center', 
               fontsize=10, fontweight='bold')
    
    # Arrows
    arrows = [
        (5, 10, 5, 8.8),
        (5, 8.8, 5, 7.6),
        (5, 7.6, 5, 6.4),
        (5, 6.4, 5, 5.2),
        (5, 3.1, 5, 2),
        (5, 2, 5, 0.8),
        (5, 0.8, 5, -0.2),
        (5, -0.2, 5, -0.8),
        (5, -0.8, 5, -1.4),
    ]
    
    for x1, y1, x2, y2 in arrows:
        ax.annotate('', xy=(x2, y2), xytext=(x1, y1),
                   arrowprops=dict(arrowstyle='->', lw=2, color='black'))
    
    # Add annotation for Transformer block
    ax.text(7.5, 4.4, '×12 layers', fontsize=12, 
           bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.5))
    
    # Add freeze indicator
    ax.text(8.5, 6.4, 'FROZEN\n❄️', fontsize=11, ha='center',
           bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.7))
    
    ax.text(8.5, 0, 'TRAINABLE\n🔥', fontsize=11, ha='center',
           bbox=dict(boxstyle='round', facecolor='#FFB254', alpha=0.7))
    
    plt.tight_layout()
    plt.savefig('/kaggle/working/vit_architecture.png', dpi=300, bbox_inches='tight')
    plt.show()

plot_vit_architecture()
print("✓ Đã lưu: vit_architecture.png")

# =================================================================
# 21. VISUALIZE FEATURE MAPS QUA TỪNG LAYER
# =================================================================
print("\n" + "="*70)
print("VISUALIZE FEATURE MAPS QUA TỪNG LAYER")
print("="*70)

# Chọn 1 ảnh để visualize
sample_idx = np.random.choice(len(test_paths))
sample_image_path = test_paths[sample_idx]
sample_true_class = class_names[test_labels[sample_idx]]

print(f"\n📸 Analyzing image: {os.path.basename(sample_image_path)}")
print(f"   True class: {sample_true_class}")

# Load và preprocess ảnh
img = tf.keras.preprocessing.image.load_img(sample_image_path)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_preprocessed = tf.image.resize(img_array, [IMG_HEIGHT, IMG_WIDTH])
img_preprocessed = tf.cast(img_preprocessed, tf.float32) / 255.0
img_input = tf.expand_dims(img_preprocessed, 0)

# Tạo models để extract outputs từ các layers
layer_names = ['feature_dense_1', 'feature_dropout_1', 'feature_dense_2', 'predictions']
layer_outputs = [full_model.get_layer(name).output for name in layer_names]
activation_model = tf.keras.Model(inputs=full_model.input, outputs=layer_outputs)

# Get activations
activations = activation_model.predict(img_input, verbose=0)

# Visualize từng bước
fig = plt.figure(figsize=(18, 12))
gs = fig.add_gridspec(4, 4, hspace=0.4, wspace=0.3)

# Original image
ax1 = fig.add_subplot(gs[0, :2])
ax1.imshow(img)
ax1.set_title(f'📸 Original Image\nTrue: {sample_true_class}', 
             fontsize=14, fontweight='bold')
ax1.axis('off')

# Preprocessed image
ax2 = fig.add_subplot(gs[0, 2:])
ax2.imshow(img_preprocessed)
ax2.set_title('🔧 Preprocessed (224×224)', fontsize=14, fontweight='bold')
ax2.axis('off')

# Feature Dense 1 (256 units)
ax3 = fig.add_subplot(gs[1, :])
features_1 = activations[0][0]  # (256,)
ax3.bar(range(len(features_1)), features_1, color='steelblue', alpha=0.7)
ax3.set_title(f'Layer 1: Dense(256) + GELU\nShape: {features_1.shape}', 
             fontsize=12, fontweight='bold')
ax3.set_xlabel('Neuron Index')
ax3.set_ylabel('Activation Value')
ax3.grid(True, alpha=0.3)

# Feature Dense 2 (128 units)
ax4 = fig.add_subplot(gs[2, :])
features_2 = activations[2][0]  # (128,)
ax4.bar(range(len(features_2)), features_2, color='coral', alpha=0.7)
ax4.set_title(f'Layer 2: Dense(128) + GELU\nShape: {features_2.shape}', 
             fontsize=12, fontweight='bold')
ax4.set_xlabel('Neuron Index')
ax4.set_ylabel('Activation Value')
ax4.grid(True, alpha=0.3)

# Output probabilities
ax5 = fig.add_subplot(gs[3, :])
predictions = activations[3][0]  # (7,)
colors = ['green' if i == test_labels[sample_idx] else 'gray' for i in range(len(class_names))]
bars = ax5.bar(class_names, predictions, color=colors, alpha=0.7)
ax5.set_title(f'Output: Softmax Probabilities\nPredicted: {class_names[np.argmax(predictions)]} ({np.max(predictions)*100:.1f}%)', 
             fontsize=12, fontweight='bold')
ax5.set_ylabel('Probability')
ax5.set_ylim(0, 1)
ax5.axhline(y=0.5, color='red', linestyle='--', alpha=0.5, label='50% threshold')
ax5.legend()
ax5.grid(True, alpha=0.3, axis='y')

plt.suptitle('🔍 Feature Maps Visualization - Layer by Layer', 
            fontsize=16, fontweight='bold', y=0.995)
plt.savefig('/kaggle/working/layer_by_layer_visualization.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Đã lưu: layer_by_layer_visualization.png")

# =================================================================
# 22. DETAILED FEATURE ANALYSIS - HEATMAP
# =================================================================
print("\n" + "="*70)
print("FEATURE ACTIVATION HEATMAP")
print("="*70)

# Visualize features dưới dạng heatmap
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Dense 1 features (256)
ax1 = axes[0, 0]
features_1_reshaped = features_1.reshape(16, 16)
im1 = ax1.imshow(features_1_reshaped, cmap='viridis', aspect='auto')
ax1.set_title('Dense Layer 1 Features (256 → 16×16)', fontsize=12, fontweight='bold')
plt.colorbar(im1, ax=ax1)

# Dense 2 features (128)
ax2 = axes[0, 1]
features_2_reshaped = features_2.reshape(8, 16)
im2 = ax2.imshow(features_2_reshaped, cmap='plasma', aspect='auto')
ax2.set_title('Dense Layer 2 Features (128 → 8×16)', fontsize=12, fontweight='bold')
plt.colorbar(im2, ax=ax2)

# Top activated neurons in Layer 1
ax3 = axes[1, 0]
top_10_indices = np.argsort(features_1)[-10:]
top_10_values = features_1[top_10_indices]
ax3.barh(range(10), top_10_values, color='steelblue')
ax3.set_yticks(range(10))
ax3.set_yticklabels([f'Neuron {i}' for i in top_10_indices])
ax3.set_xlabel('Activation Value')
ax3.set_title('Top 10 Activated Neurons (Layer 1)', fontsize=12, fontweight='bold')
ax3.grid(True, alpha=0.3, axis='x')

# Top activated neurons in Layer 2
ax4 = axes[1, 1]
top_10_indices_2 = np.argsort(features_2)[-10:]
top_10_values_2 = features_2[top_10_indices_2]
ax4.barh(range(10), top_10_values_2, color='coral')
ax4.set_yticks(range(10))
ax4.set_yticklabels([f'Neuron {i}' for i in top_10_indices_2])
ax4.set_xlabel('Activation Value')
ax4.set_title('Top 10 Activated Neurons (Layer 2)', fontsize=12, fontweight='bold')
ax4.grid(True, alpha=0.3, axis='x')

plt.suptitle('🔥 Feature Activation Analysis', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('/kaggle/working/feature_activation_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Đã lưu: feature_activation_heatmap.png")

# =================================================================
# 23. TRAINING PIPELINE DIAGRAM
# =================================================================
print("\n" + "="*70)
print("COMPLETE TRAINING PIPELINE")
print("="*70)

def plot_training_pipeline():
    """Vẽ complete training pipeline"""
    fig, ax = plt.subplots(figsize=(16, 10))
    ax.set_xlim(0, 16)
    ax.set_ylim(0, 11)
    ax.axis('off')
    
    # Title
    ax.text(8, 10.5, 'Complete Training Pipeline - ViT Transfer Learning + SVM', 
            ha='center', fontsize=18, fontweight='bold')
    
    # Stage 1: Data Preparation
    ax.text(2, 9.5, '📊 Stage 1: Data Preparation', fontsize=12, fontweight='bold')
    boxes_stage1 = [
        (0.5, 8.5, 3, 0.6, 'Load Images\n8069 train\n2306 val\n1156 test', '#E8F4F8'),
        (0.5, 7.7, 3, 0.6, 'Augmentation\nFlip, Rotate\nZoom, Contrast', '#B8E6F0'),
        (0.5, 6.9, 3, 0.6, 'Preprocess\nResize 224×224\nNormalize /255', '#88D8E8'),
    ]
    for x, y, w, h, text, color in boxes_stage1:
        rect = plt.Rectangle((x, y), w, h, facecolor=color, edgecolor='black', linewidth=2)
        ax.add_patch(rect)
        ax.text(x + w/2, y + h/2, text, ha='center', va='center', fontsize=9)
    
    # Stage 2: ViT Transfer Learning
    ax.text(6, 9.5, '🤖 Stage 2: ViT Transfer Learning', fontsize=12, fontweight='bold')
    boxes_stage2 = [
        (4.5, 8.5, 3, 0.6, 'ViT-base Backbone\n86M params\n❄️ FROZEN', '#B8E6F0'),
        (4.5, 7.7, 3, 0.6, 'Dense(256) + Dropout(0.5)\n🔥 TRAINABLE', '#FFE5B4'),
        (4.5, 6.9, 3, 0.6, 'Dense(128) + Dropout(0.4)\n🔥 TRAINABLE', '#FFD494'),
        (4.5, 6.1, 3, 0.6, 'Softmax(7)\n🔥 TRAINABLE', '#FFC374'),
    ]
    for x, y, w, h, text, color in boxes_stage2:
        rect = plt.Rectangle((x, y), w, h, facecolor=color, edgecolor='black', linewidth=2)
        ax.add_patch(rect)
        ax.text(x + w/2, y + h/2, text, ha='center', va='center', fontsize=9, fontweight='bold')
    
    # Stage 3: Training Config
    ax.text(10, 9.5, '⚙️ Stage 3: Training Config', fontsize=12, fontweight='bold')
    boxes_stage3 = [
        (8.5, 8.5, 3, 0.6, 'Optimizer: AdamW\nLR: 0.001', '#E8F4F8'),
        (8.5, 7.7, 3, 0.6, 'Loss: Categorical\nCrossentropy', '#B8E6F0'),
        (8.5, 6.9, 3, 0.6, 'Batch: 32\nEpochs: 50', '#88D8E8'),
        (8.5, 6.1, 3, 0.6, 'Early Stop\npatience=10', '#58CAE0'),
    ]
    for x, y, w, h, text, color in boxes_stage3:
        rect = plt.Rectangle((x, y), w, h, facecolor=color, edgecolor='black', linewidth=2)
        ax.add_patch(rect)
        ax.text(x + w/2, y + h/2, text, ha='center', va='center', fontsize=9)
    
    # Stage 4: Feature Extraction
    ax.text(2, 5.5, '🔍 Stage 4: Feature Extraction', fontsize=12, fontweight='bold')
    boxes_stage4 = [
        (0.5, 4.5, 3, 0.6, 'Extract Features\nfrom Dense(128)', '#88D8E8'),
        (0.5, 3.7, 3, 0.6, 'StandardScaler\nNormalization', '#B8E6F0'),
        (0.5, 2.9, 3, 0.6, 'Features Shape\n(N, 128)', '#E8F4F8'),
    ]
    for x, y, w, h, text, color in boxes_stage4:
        rect = plt.Rectangle((x, y), w, h, facecolor=color, edgecolor='black', linewidth=2)
        ax.add_patch(rect)
        ax.text(x + w/2, y + h/2, text, ha='center', va='center', fontsize=9)
    
    # Stage 5: SVM Training
    ax.text(6, 5.5, '🎯 Stage 5: SVM Classifier', fontsize=12, fontweight='bold')
    boxes_stage5 = [
        (4.5, 4.5, 3, 0.6, 'SVM (RBF Kernel)', '#FFE5B4'),
        (4.5, 3.7, 3, 0.6, 'C = 10\ngamma = scale', '#FFD494'),
        (4.5, 2.9, 3, 0.6, 'Train on\n128-d features', '#FFC374'),
    ]
    for x, y, w, h, text, color in boxes_stage5:
        rect = plt.Rectangle((x, y), w, h, facecolor=color, edgecolor='black', linewidth=2)
        ax.add_patch(rect)
        ax.text(x + w/2, y + h/2, text, ha='center', va='center', fontsize=9, fontweight='bold')
    
    # Stage 6: Results
    ax.text(10, 5.5, '📊 Stage 6: Results', fontsize=12, fontweight='bold')
    boxes_stage6 = [
        (8.5, 4.5, 3, 0.6, 'ViT + Softmax\n100.00%', '#90EE90'),
        (8.5, 3.7, 3, 0.6, 'ViT + SVM\n100.00%', '#90EE90'),
        (8.5, 2.9, 3, 0.6, '0 errors\non 1156 images', '#98FB98'),
    ]
    for x, y, w, h, text, color in boxes_stage6:
        rect = plt.Rectangle((x, y), w, h, facecolor=color, edgecolor='darkgreen', linewidth=2)
        ax.add_patch(rect)
        ax.text(x + w/2, y + h/2, text, ha='center', va='center', fontsize=10, fontweight='bold')
    
    # Arrows connecting stages
    arrows = [
        # Stage 1 -> 2
        (2, 8.8, 4.5, 8.8),
        # Stage 2 -> 4
        (6, 6.1, 2, 4.8),
        # Stage 4 -> 5
        (3.5, 3.5, 4.5, 3.5),
        # Stage 5 -> 6
        (7.5, 3.5, 8.5, 3.5),
    ]
    
    for x1, y1, x2, y2 in arrows:
        ax.annotate('', xy=(x2, y2), xytext=(x1, y1),
                   arrowprops=dict(arrowstyle='->', lw=3, color='black'))
    
    # Add legend
    legend_elements = [
        plt.Rectangle((0, 0), 1, 1, fc='#E8F4F8', ec='black', label='Data Processing'),
        plt.Rectangle((0, 0), 1, 1, fc='#FFE5B4', ec='black', label='Model Training'),
        plt.Rectangle((0, 0), 1, 1, fc='#90EE90', ec='darkgreen', label='Results'),
    ]
    ax.legend(handles=legend_elements, loc='upper left', fontsize=10)
    
    # Add statistics box
    stats_text = """
    📈 Training Statistics:
    • Total Parameters: 86M (ViT) + 1M (Head)
    • Training Time: ~20 mins
    • GPU: Tesla P100
    • Final Loss: 0.0006
    """
    ax.text(12, 1.5, stats_text, fontsize=9, 
           bbox=dict(boxstyle='round', facecolor='lightyellow', alpha=0.8))
    
    plt.tight_layout()
    plt.savefig('/kaggle/working/complete_pipeline.png', dpi=300, bbox_inches='tight')
    plt.show()

plot_training_pipeline()
print("✓ Đã lưu: complete_pipeline.png")

# =================================================================
# 24. FINAL SUMMARY
# =================================================================
print("\n" + "="*70)
print("📊 FINAL SUMMARY - ALL VISUALIZATIONS")
print("="*70)
print("\n✅ Files đã tạo:")
print("-"*70)
viz_files = [
    "all_incorrect_predictions.png - Grid ảnh dự đoán sai",
    "model_summary.txt - Model architecture text",
    "vit_architecture.png - ViT architecture diagram",
    "layer_by_layer_visualization.png - Feature maps qua từng layer",
    "feature_activation_heatmap.png - Heatmap activations",
    "complete_pipeline.png - Complete training pipeline",
    "confusion_matrix_vit_transfer_svm.png - Confusion matrix",
    "correct_predictions.png - 3 ảnh dự đoán đúng",
    "training_curves.png - Training history",
]

for i, file in enumerate(viz_files, 1):
    print(f"{i:2d}. ✓ {file}")

print("\n" + "="*70)
print("🎯 USE CASES:")
print("-"*70)
print("📝 Presentation slides:")
print("   → vit_architecture.png")
print("   → complete_pipeline.png")
print("   → training_curves.png")
print("\n🔬 Technical analysis:")
print("   → layer_by_layer_visualization.png")
print("   → feature_activation_heatmap.png")
print("   → model_summary.txt")
print("\n📊 Results showcase:")
print("   → confusion_matrix_vit_transfer_svm.png")
print("   → correct_predictions.png")
print("   → all_incorrect_predictions.png")
print("="*70)
# Out:
# ...
# PHÂN TÍCH CHI TIẾT ẢNH DỰ ĐOÁN SAI
# ...
#
# ✅ HOÀN HẢO! Không có ảnh nào dự đoán sai!
#
# ...
# MODEL SUMMARY & ARCHITECTURE
# ...
#
# 📋 FULL MODEL SUMMARY:
# ----------------------------------------------------------------------
# Model: "ViT_Transfer_Full"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ pixel_values (InputLayer)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization (Normalization)   │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ permute (Permute)               │ (None, 3, 224, 224)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
