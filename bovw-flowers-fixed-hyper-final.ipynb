o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/14981797828_7eccb85449_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/19678351486_1530c7b376_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/41003194115_6c59e67cc7_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/9603569480_ea72f8c886_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/29037515351_2b0c79473b_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/36970009966_88f9990819_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/22567613862_8b66e7c488_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/6704149553_1f7690f7e0_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/27729230412_4d26dfa9ff_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/22329538131_832cde8585_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/18974187164_52c5a6c184_b.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/27249029345_b298b7dc29_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/1340840523_d9c7822731_h.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/43775141300_0e87ebf9f3_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/5461415145_4e0b4bc233_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/10539258363_e37360d677_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/9321941863_f49824bbc8_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/5402871648_33fbe0c593_h.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/2298500353_11510586a6_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/15062019896_1483d78be5_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/2480343052_01fe9e8d0c_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/37537007156_07aaad7f31_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/7622630862_b784a04d02_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/2480340274_02ce2b010b_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/35854556842_d1c31c4617_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/3510923638_ed24713b61_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/9246201815_1afa9edde0_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/37216485931_0e0d232fcd_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/26528859124_ee2fa0e7b0_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/26704287686_fb7d5ede8e_h.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/443407148_e22eee42b6_h.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/44125158964_0324d377b0_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/5179159949_c94f4bc8bc_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/12229407154_17cf151d87_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/8029141638_b11f6c95c7_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/14926532494_aa4dda1f06_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/26929892086_03a30b244d_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/5993847284_fa9b214f25_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/37047621714_53534d53e3_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/16955613031_c7d122e559_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/2072632190_88153c0a66_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/13882760725_64985062cc_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/30294450746_35b703a0ff_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/2480340422_af77d8fc3f_o.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/16252466432_62aa740b86_k.jpg
# /kaggle/input/flowerdatasets/flowers/train/rose/22515218314_eb59fc32a6_o.jpg

# %% [markdown]
# # import và setup

# %%
import os
from pathlib import Path

import cv2
import numpy as np

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
)
from sklearn.cluster import MiniBatchKMeans

import matplotlib.pyplot as plt
import seaborn as sns
import pickle

print("✅ Libraries imported.")
# Out:
# ✅ Libraries imported.

# %% [markdown]
# # Path

# %%
BASE_DIR = "/kaggle/input/flowerdatasets/flowers"
TRAIN_DIR = os.path.join(BASE_DIR, "train")
VAL_DIR   = os.path.join(BASE_DIR, "val")
TEST_DIR  = os.path.join(BASE_DIR, "test")

base_dir = Path(BASE_DIR)
train_dir = Path(TRAIN_DIR)
val_dir   = Path(VAL_DIR)
test_dir  = Path(TEST_DIR)

class_names = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
print("Classes:", class_names)
# Out:
# Classes: ['daisy', 'dandelion', 'lily', 'orchid', 'rose', 'sunflower', 'tulip']

# %% [markdown]
# # RootSIFT extractor

# %%
sift = cv2.SIFT_create()

def extract_rootsift_descriptors(img_gray, max_kp=500):
    """
    Trích xuất RootSIFT descriptors từ ảnh grayscale.
    img_gray: ảnh grayscale (ndarray)
    """
    keypoints, desc = sift.detectAndCompute(img_gray, None)
    if desc is None:
        return None

    if desc.shape[0] > max_kp:
        desc = desc[:max_kp]
        
    # ======= RootSIFT =======
    desc = desc.astype("float32")
    # 1) L1 normalize từng descriptor
    desc /= (desc.sum(axis=1, keepdims=True) + 1e-7)
    # 2) Căn bậc hai từng phần tử
    desc = np.sqrt(desc)

    return desc

# %% [markdown]
# # Thu thập SIFT descriptor từ train & train codebook (BoVW)

# %%
# ============================================
# Thu thập SIFT descriptors từ train
# ============================================

def collect_descriptors_from_train(train_folder, max_images_per_class=250):
    """
    Thu thập tất cả SIFT descriptors từ tập train để train codebook.
    """
    all_desc = []
    train_folder = Path(train_folder)

    for cls in class_names:
        cls_dir = train_folder / cls
        img_files = []
        for ext in ("*.jpg", "*.jpeg", "*.png"):
            img_files.extend(cls_dir.glob(ext))

        img_files = img_files[:max_images_per_class]
        print(f"[Collect] {cls}: {len(img_files)} images")
        
        for img_path in img_files:
            img = cv2.imread(str(img_path))
            if img is None:
                continue
            img_gray = cv2.cvtColor(cv2.resize(img, (256, 256)), cv2.COLOR_BGR2GRAY)
            desc = extract_rootsift_descriptors(img_gray)
            if desc is not None:
                all_desc.append(desc)

    if not all_desc:
        return None

    all_desc = np.vstack(all_desc)
    return all_desc


print("\n" + "="*50)
print("Collecting SIFT descriptors from training set...")
print("="*50)

all_desc = collect_descriptors_from_train(train_dir, max_images_per_class=250)
print("All descriptors shape:", all_desc.shape)


# ============================================
# Train Codebook (K-means)
# ============================================

K = 700  # Số "visual words"

print("\n" + "="*50)
print(f"Training MiniBatchKMeans with K={K} ...")
print("="*50)

kmeans = MiniBatchKMeans(
    n_clusters=K,
    batch_size=2000,
    n_init=10,
    random_state=42,
    verbose=1
)
kmeans.fit(all_desc)
print("✅ Codebook trained.")


# ============================================
# Trích BoVW cho 1 ảnh
# ============================================

def image_to_bovw(img_path):
    """
    Trả về feature vector = BoVW histogram từ RootSIFT.
    """
    img = cv2.imread(str(img_path))
    if img is None:
        # fallback vector zeros
        return np.zeros(K, dtype=np.float32)

    img_resized = cv2.resize(img, (256, 256))
    gray = cv2.cvtColor(img_resized, cv2.COLOR_BGR2GRAY)

    # --- BoVW từ RootSIFT ---
    desc = extract_rootsift_descriptors(gray)
    if desc is None:
        bovw_hist = np.zeros(K, dtype=np.float32)
    else:
        words = kmeans.predict(desc)
        bovw_hist, _ = np.histogram(words, bins=np.arange(K+1))
        bovw_hist = bovw_hist.astype("float32")
        # Hellinger normalization
        bovw_hist /= (bovw_hist.sum() + 1e-7)
        bovw_hist = np.sqrt(bovw_hist)

    return bovw_hist
# Out:
# ==================================================
# Collecting SIFT descriptors from training set...
# ==================================================
# [Collect] daisy: 250 images
# [Collect] dandelion: 250 images
# [Collect] lily: 250 images
# [Collect] orchid: 250 images
# [Collect] rose: 250 images
# [Collect] sunflower: 250 images
# [Collect] tulip: 250 images
# All descriptors shape: (598336, 128)
#
# ==================================================
# Training MiniBatchKMeans with K=700 ...
# ==================================================
# Init 1/10 with method k-means++
# Inertia for init 1/10: 1590.5478515625
# Init 2/10 with method k-means++
# Inertia for init 2/10: 1591.84912109375
# Init 3/10 with method k-means++
# Inertia for init 3/10: 1585.302978515625
# Init 4/10 with method k-means++
# Inertia for init 4/10: 1595.1273193359375
# Init 5/10 with method k-means++
# Inertia for init 5/10: 1600.3006591796875
# Init 6/10 with method k-means++
# Inertia for init 6/10: 1600.809814453125
# Init 7/10 with method k-means++
# Inertia for init 7/10: 1592.4329833984375
# Init 8/10 with method k-means++
# Inertia for init 8/10: 1592.3829345703125
# Init 9/10 with method k-means++
# Inertia for init 9/10: 1594.396728515625
# Init 10/10 with method k-means++
# Inertia for init 10/10: 1586.8818359375
# [MiniBatchKMeans] Reassigning 93 cluster centers.
# Minibatch step 1/29916: mean batch inertia: 0.2642216796875
# Minibatch step 2/29916: mean batch inertia: 0.22220611572265625, ewa inertia: 0.22220611572265625
# Minibatch step 3/29916: mean batch inertia: 0.2141614990234375, ewa inertia: 0.22215233588487773
# Minibatch step 4/29916: mean batch inertia: 0.2082640380859375, ewa inertia: 0.2220594898947488
# Minibatch step 5/29916: mean batch inertia: 0.2055791778564453, ewa inertia: 0.22194931578191068
# Minibatch step 6/29916: mean batch inertia: 0.20262046813964843, ewa inertia: 0.2218200986508139
# Minibatch step 7/29916: mean batch inertia: 0.20270994567871095, ewa inertia: 0.2216923435364078
# Minibatch step 8/29916: mean batch inertia: 0.20086790466308593, ewa inertia: 0.2215531280850931
# [MiniBatchKMeans] Reassigning 86 cluster centers.
# Minibatch step 9/29916: mean batch inertia: 0.19966900634765625, ewa inertia: 0.22140682844634477
# Minibatch step 10/29916: mean batch inertia: 0.19899517822265625, ewa inertia: 0.22125700217637523
# Minibatch step 11/29916: mean batch inertia: 0.197891845703125, ewa inertia: 0.22110080153042988
# Minibatch step 12/29916: mean batch inertia: 0.1993041076660156, ewa inertia: 0.2209550863641312
# [MiniBatchKMeans] Reassigning 86 cluster centers.
# Minibatch step 13/29916: mean batch inertia: 0.19845756530761718, ewa inertia: 0.22080468603083062
# Minibatch step 14/29916: mean batch inertia: 0.19596163940429687, ewa inertia: 0.22063860539983815
# Minibatch step 15/29916: mean batch inertia: 0.1965880889892578, ewa inertia: 0.22047782298851756
# Minibatch step 16/29916: mean batch inertia: 0.19571356201171874, ewa inertia: 0.22031226905501988
# Minibatch step 17/29916: mean batch inertia: 0.1953919677734375, ewa inertia: 0.22014567196153187
# Minibatch step 18/29916: mean batch inertia: 0.19420140075683595, ewa inertia: 0.2199722294286135
# Minibatch step 19/29916: mean batch inertia: 0.19204127502441407, ewa inertia: 0.21978550552951182
# Minibatch step 20/29916: mean batch inertia: 0.1933015441894531, ewa inertia: 0.21960845506236665
# Minibatch step 21/29916: mean batch inertia: 0.19348199462890625, ewa inertia: 0.21943379455878115
# Minibatch step 22/29916: mean batch inertia: 0.19422567749023437, ewa inertia: 0.21926527336040266
# Minibatch step 23/29916: mean batch inertia: 0.194014404296875, ewa inertia: 0.21909646635656685
# Minibatch step 24/29916: mean batch inertia: 0.1934583435058594, ewa inertia: 0.21892507048533905
# [MiniBatchKMeans] Reassigning 32 cluster centers.
# Minibatch step 25/29916: mean batch inertia: 0.19303550720214843, ewa inertia: 0.2187519936855878
# Minibatch step 26/29916: mean batch inertia: 0.19313104248046875, ewa inertia: 0.21858071261017295
# Minibatch step 27/29916: mean batch inertia: 0.19398843383789063, ewa inertia: 0.21841630841138676
# Minibatch step 28/29916: mean batch inertia: 0.19180085754394532, ewa inertia: 0.21823837891100525
# Minibatch step 29/29916: mean batch inertia: 0.19270526123046874, ewa inertia: 0.21806768501990015
# Minibatch step 30/29916: mean batch inertia: 0.19259535217285156, ewa inertia: 0.21789739748730866
# Minibatch step 31/29916: mean batch inertia: 0.190521728515625, ewa inertia: 0.21771438578004879
# Minibatch step 32/29916: mean batch inertia: 0.19187635803222655, ewa inertia: 0.2175416535054422
# [MiniBatchKMeans] Reassigning 29 cluster centers.
# Minibatch step 33/29916: mean batch inertia: 0.1928930206298828, ewa inertia: 0.21737687256844138
# Minibatch step 34/29916: mean batch inertia: 0.19263999938964843, ewa inertia: 0.21721150172773593
# Minibatch step 35/29916: mean batch inertia: 0.19184983825683594, ewa inertia: 0.21704195404159315
# Minibatch step 36/29916: mean batch inertia: 0.19177268981933593, ewa inertia: 0.21687302406251943
# Minibatch step 37/29916: mean batch inertia: 0.19230271911621094, ewa inertia: 0.21670876676306236
# Minibatch step 38/29916: mean batch inertia: 0.19169441223144532, ewa inertia: 0.21654154090518216
# Minibatch step 39/29916: mean batch inertia: 0.1914552001953125, ewa inertia: 0.21637383380560535
# Minibatch step 40/29916: mean batch inertia: 0.19087619018554688, ewa inertia: 0.2162033770655404
# [MiniBatchKMeans] Reassigning 19 cluster centers.
# Minibatch step 41/29916: mean batch inertia: 0.19157049560546874, ewa inertia: 0.2160387014298363
# Minibatch step 42/29916: mean batch inertia: 0.19375886535644532, ewa inertia: 0.21588975636327085
# Minibatch step 43/29916: mean batch inertia: 0.1895970001220703, ewa inertia: 0.2157139841396497
# Minibatch step 44/29916: mean batch inertia: 0.19261724853515624, ewa inertia: 0.21555957793976907
# Minibatch step 45/29916: mean batch inertia: 0.19084603881835938, ewa inertia: 0.21539436309180607
# Minibatch step 46/29916: mean batch inertia: 0.19122213745117186, ewa inertia: 0.21523276703045177
# Minibatch step 47/29916: mean batch inertia: 0.19218759155273438, ewa inertia: 0.21507870552011416
# Minibatch step 48/29916: mean batch inertia: 0.1899127197265625, ewa inertia: 0.21491046597755833
# Minibatch step 49/29916: mean batch inertia: 0.19044271850585937, ewa inertia: 0.21474689429489988
# Minibatch step 50/29916: mean batch inertia: 0.19164410400390625, ewa inertia: 0.2145924476182545
# Minibatch step 51/29916: mean batch inertia: 0.19154188537597655, ewa inertia: 0.21443835009634105
# Minibatch step 52/29916: mean batch inertia: 0.18914540100097657, ewa inertia: 0.21426926177925307
# [MiniBatchKMeans] Reassigning 15 cluster centers.
# Minibatch step 53/29916: mean batch inertia: 0.1927774658203125, ewa inertia: 0.2141255849151518
# Minibatch step 54/29916: mean batch inertia: 0.1896595916748047, ewa inertia: 0.2139620249598734
# Minibatch step 55/29916: mean batch inertia: 0.19068276977539061, ewa inertia: 0.21380639858086303
# Minibatch step 56/29916: mean batch inertia: 0.19154302978515625, ewa inertia: 0.21365756360127322
# Minibatch step 57/29916: mean batch inertia: 0.18950077819824218, ewa inertia: 0.21349607076093052
# Minibatch step 58/29916: mean batch inertia: 0.1908675994873047, ewa inertia: 0.21334479499978837
# Minibatch step 59/29916: mean batch inertia: 0.19048439025878905, ewa inertia: 0.21319196871800403
# Minibatch step 60/29916: mean batch inertia: 0.18930062866210937, ewa inertia: 0.2130322504317814
# Minibatch step 61/29916: mean batch inertia: 0.189727783203125, ewa inertia: 0.21287645550531917
# Minibatch step 62/29916: mean batch inertia: 0.19080722045898438, ewa inertia: 0.2127289183478555
# Minibatch step 63/29916: mean batch inertia: 0.18942082214355468, ewa inertia: 0.21257309916098055
# Minibatch step 64/29916: mean batch inertia: 0.1894861297607422, ewa inertia: 0.2124187582500876
# [MiniBatchKMeans] Reassigning 7 cluster centers.
# Minibatch step 65/29916: mean batch inertia: 0.1894986572265625, ewa inertia: 0.21226553288696598
# Minibatch step 66/29916: mean batch inertia: 0.189968505859375, ewa inertia: 0.2121164728955057
# Minibatch step 67/29916: mean batch inertia: 0.18853387451171874, ewa inertia: 0.21195881860781307
# Minibatch step 68/29916: mean batch inertia: 0.19086846923828124, ewa inertia: 0.21181782549276565
# Minibatch step 69/29916: mean batch inertia: 0.19065878295898436, ewa inertia: 0.21167637315046503
# Minibatch step 70/29916: mean batch inertia: 0.189712890625, ewa inertia: 0.21152954296930981
# Minibatch step 71/29916: mean batch inertia: 0.1883520050048828, ewa inertia: 0.21137459658983182
# Minibatch step 72/29916: mean batch inertia: 0.19018115234375, ewa inertia: 0.2112329142653486
# Minibatch step 73/29916: mean batch inertia: 0.19039144897460938, ewa inertia: 0.21109358498909964
# Minibatch step 74/29916: mean batch inertia: 0.18899063110351563, ewa inertia: 0.2109458224145934
# Minibatch step 75/29916: mean batch inertia: 0.19036445617675782, ewa inertia: 0.21080823195144077
# Minibatch step 76/29916: mean batch inertia: 0.1897847900390625, ewa inertia: 0.21066768612584497
# [MiniBatchKMeans] Reassigning 7 cluster centers.
# Minibatch step 77/29916: mean batch inertia: 0.18832575988769532, ewa inertia: 0.2105183259743708
# Minibatch step 78/29916: mean batch inertia: 0.18984574890136718, ewa inertia: 0.21038012574892592
# Minibatch step 79/29916: mean batch inertia: 0.18773336791992187, ewa inertia: 0.21022872773858053
# Minibatch step 80/29916: mean batch inertia: 0.18711672973632812, ewa inertia: 0.2100742195065825
# Minibatch step 81/29916: mean batch inertia: 0.18801502990722657, ewa inertia: 0.2099267495048988
# Minibatch step 82/29916: mean batch inertia: 0.18922599792480468, ewa inertia: 0.20978836092735742
# Minibatch step 83/29916: mean batch inertia: 0.18899626159667968, ewa inertia: 0.2096493616722174
# Minibatch step 84/29916: mean batch inertia: 0.18985690307617187, ewa inertia: 0.20951704521111908
# Minibatch step 85/29916: mean batch inertia: 0.18923402404785156, ewa inertia: 0.2093814492432062
# Minibatch step 86/29916: mean batch inertia: 0.18858030700683595, ewa inertia: 0.20924238953447102
# Minibatch step 87/29916: mean batch inertia: 0.18786885070800782, ewa inertia: 0.20909950324245521
# Minibatch step 88/29916: mean batch inertia: 0.19061253356933594, ewa inertia: 0.20897591423042272
# [MiniBatchKMeans] Reassigning 6 cluster centers.
# Minibatch step 89/29916: mean batch inertia: 0.189246826171875, ewa inertia: 0.2088440214137756
# Minibatch step 90/29916: mean batch inertia: 0.19020414733886717, ewa inertia: 0.2087194102058783
# Minibatch step 91/29916: mean batch inertia: 0.18975685119628907, ewa inertia: 0.20859264178601064
# Minibatch step 92/29916: mean batch inertia: 0.19013720703125, ewa inertia: 0.20846926359108195
# Minibatch step 93/29916: mean batch inertia: 0.18777377319335936, ewa inertia: 0.20833091018557487
# Minibatch step 94/29916: mean batch inertia: 0.18855706787109375, ewa inertia: 0.2081987181779639
# Minibatch step 95/29916: mean batch inertia: 0.18878701782226562, ewa inertia: 0.20806894716025517
# Minibatch step 96/29916: mean batch inertia: 0.18785659790039064, ewa inertia: 0.2079338236478542
# [MiniBatchKMeans] Reassigning 3 cluster centers.
# Minibatch step 97/29916: mean batch inertia: 0.1881892547607422, ewa inertia: 0.20780182733883695
# Minibatch step 98/29916: mean batch inertia: 0.18823545837402345, ewa inertia: 0.207671022331192
# Minibatch step 99/29916: mean batch inertia: 0.18842790222167968, ewa inertia: 0.2075423783054372
# Minibatch step 100/29916: mean batch inertia: 0.18951528930664063, ewa inertia: 0.20742186368575768
# Minibatch step 101/29916: mean batch inertia: 0.18744340515136718, ewa inertia: 0.20728830377865254
# Minibatch step 102/29916: mean batch inertia: 0.1888249053955078, ewa inertia: 0.2071648723453088
# Minibatch step 103/29916: mean batch inertia: 0.18944586181640624, ewa inertia: 0.2070464172905226
# Minibatch step 104/29916: mean batch inertia: 0.18616165161132814, ewa inertia: 0.20690679854269856
# Minibatch step 105/29916: mean batch inertia: 0.18972134399414062, ewa inertia: 0.20679191041411177
# Minibatch step 106/29916: mean batch inertia: 0.18752447509765624, ewa inertia: 0.2066631038364376
# Minibatch step 107/29916: mean batch inertia: 0.18851702880859375, ewa inertia: 0.2065417937718563
# Minibatch step 108/29916: mean batch inertia: 0.18804743957519532, ewa inertia: 0.20641815539283806
# [MiniBatchKMeans] Reassigning 2 cluster centers.
# Minibatch step 109/29916: mean batch inertia: 0.1889964599609375, ewa inertia: 0.2063016879476899
# Minibatch step 110/29916: mean batch inertia: 0.18646658325195312, ewa inertia: 0.206169086389065
# Minibatch step 111/29916: mean batch inertia: 0.18813560485839845, ewa inertia: 0.20604852903405826
# Minibatch step 112/29916: mean batch inertia: 0.18878900146484376, ewa inertia: 0.2059331457128248
# Minibatch step 113/29916: mean batch inertia: 0.18917913818359375, ewa inertia: 0.20582114189203998
# Minibatch step 114/29916: mean batch inertia: 0.19048031616210936, ewa inertia: 0.20571858546828595
# Minibatch step 115/29916: mean batch inertia: 0.19006239318847656, ewa inertia: 0.20561392075739687
# Minibatch step 116/29916: mean batch inertia: 0.1894353790283203, ewa inertia: 0.2055057640381629
# Minibatch step 117/29916: mean batch inertia: 0.18816517639160157, ewa inertia: 0.20538983881444073
# Minibatch step 118/29916: mean batch inertia: 0.18796771240234375, ewa inertia: 0.2052733684881056
# Minibatch step 119/29916: mean batch inertia: 0.18822706604003905, ewa inertia: 0.20515941061855672
# Minibatch step 120/29916: mean batch inertia: 0.187818603515625, ewa inertia: 0.20504348392772576
# [MiniBatchKMeans] Reassigning 2 cluster centers.
# Minibatch step 121/29916: mean batch inertia: 0.18874862670898437, ewa inertia: 0.20493454961666865
# Minibatch step 122/29916: mean batch inertia: 0.18804400634765625, ewa inertia: 0.20482163302772957
# Minibatch step 123/29916: mean batch inertia: 0.18878677368164062, ewa inertia: 0.20471443685335902
# Minibatch step 124/29916: mean batch inertia: 0.18866018676757812, ewa inertia: 0.2046071110480969
# Minibatch step 125/29916: mean batch inertia: 0.18916444396972656, ewa inertia: 0.20450387379498788
# Minibatch step 126/29916: mean batch inertia: 0.1895517120361328, ewa inertia: 0.20440391566598126
# Minibatch step 127/29916: mean batch inertia: 0.1867173309326172, ewa inertia: 0.20428567738398723
# Minibatch step 128/29916: mean batch inertia: 0.18705303955078126, ewa inertia: 0.204170473825904
# Minibatch step 129/29916: mean batch inertia: 0.18925927734375, ewa inertia: 0.20407078955779318
# Minibatch step 130/29916: mean batch inertia: 0.18837081909179687, ewa inertia: 0.2039658321811576
# Minibatch step 131/29916: mean batch inertia: 0.18921502685546876, ewa inertia: 0.2038672201593325
# Minibatch step 132/29916: mean batch inertia: 0.18801063537597656, ewa inertia: 0.20376121578532017
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# Minibatch step 133/29916: mean batch inertia: 0.18578802490234375, ewa inertia: 0.2036410614850982
# Minibatch step 134/29916: mean batch inertia: 0.18938827514648438, ewa inertia: 0.20354577881771432
# Minibatch step 135/29916: mean batch inertia: 0.1877867126464844, ewa inertia: 0.20344042637471826
# Minibatch step 136/29916: mean batch inertia: 0.18959687805175782, ewa inertia: 0.2033478795435983
# Minibatch step 137/29916: mean batch inertia: 0.18787399291992188, ewa inertia: 0.20324443358171607
# Minibatch step 138/29916: mean batch inertia: 0.1889062042236328, ewa inertia: 0.20314857971101724
# Minibatch step 139/29916: mean batch inertia: 0.1887727508544922, ewa inertia: 0.2030524744803093
# Minibatch step 140/29916: mean batch inertia: 0.18734266662597657, ewa inertia: 0.20294745133880654
# Minibatch step 141/29916: mean batch inertia: 0.1869250946044922, ewa inertia: 0.2028403387468437
# Minibatch step 142/29916: mean batch inertia: 0.18652247619628906, ewa inertia: 0.202731250640639
# Minibatch step 143/29916: mean batch inertia: 0.18839154052734375, ewa inertia: 0.2026353868708016
# Minibatch step 144/29916: mean batch inertia: 0.18780143737792968, ewa inertia: 0.20253621901393917
# Minibatch step 145/29916: mean batch inertia: 0.18921356201171874, ewa inertia: 0.20244715444328937
# Minibatch step 146/29916: mean batch inertia: 0.18693035888671874, ewa inertia: 0.20234342162678914
# Minibatch step 147/29916: mean batch inertia: 0.18776292419433593, ewa inertia: 0.2022459481465768
# Minibatch step 148/29916: mean batch inertia: 0.18902674865722657, ewa inertia: 0.2021575752096576
# Minibatch step 149/29916: mean batch inertia: 0.1865277099609375, ewa inertia: 0.2020530865001262
# Minibatch step 150/29916: mean batch inertia: 0.18681158447265625, ewa inertia: 0.20195119407477077
# Minibatch step 151/29916: mean batch inertia: 0.18627763366699218, ewa inertia: 0.2018464132545455
# Minibatch step 152/29916: mean batch inertia: 0.1866583251953125, ewa inertia: 0.20174487791202625
# Minibatch step 153/29916: mean batch inertia: 0.18782444763183595, ewa inertia: 0.2016518171099686
# Minibatch step 154/29916: mean batch inertia: 0.18861181640625, ewa inertia: 0.2015646421520187
# Minibatch step 155/29916: mean batch inertia: 0.1879380340576172, ewa inertia: 0.20147354560880373
# Minibatch step 156/29916: mean batch inertia: 0.18752214050292967, ewa inertia: 0.20138027773397146
# Minibatch step 157/29916: mean batch inertia: 0.18733938598632813, ewa inertia: 0.2012864116234174
# Minibatch step 158/29916: mean batch inertia: 0.18901019287109375, ewa inertia: 0.20120434269736184
# Minibatch step 159/29916: mean batch inertia: 0.18792822265625, ewa inertia: 0.20111558923540904
# Minibatch step 160/29916: mean batch inertia: 0.18838101196289062, ewa inertia: 0.2010304560928989
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# Minibatch step 161/29916: mean batch inertia: 0.18580335998535155, ewa inertia: 0.20092865997393888
# Minibatch step 162/29916: mean batch inertia: 0.18727149963378906, ewa inertia: 0.20083735918297893
# Minibatch step 163/29916: mean batch inertia: 0.1880044708251953, ewa inertia: 0.2007515688116144
# Minibatch step 164/29916: mean batch inertia: 0.18818455505371093, ewa inertia: 0.2006675558640086
# Minibatch step 165/29916: mean batch inertia: 0.18690609741210937, ewa inertia: 0.20057555781974992
# Minibatch step 166/29916: mean batch inertia: 0.186344482421875, ewa inertia: 0.20048042029425592
# Minibatch step 167/29916: mean batch inertia: 0.18747329711914062, ewa inertia: 0.20039346512902217
# Minibatch step 168/29916: mean batch inertia: 0.1880394287109375, ewa inertia: 0.20031087597663425
# Minibatch step 169/29916: mean batch inertia: 0.18785028076171875, ewa inertia: 0.20022757445782519
# Minibatch step 170/29916: mean batch inertia: 0.18655087280273439, ewa inertia: 0.20013614302934865
# Minibatch step 171/29916: mean batch inertia: 0.1889895477294922, ewa inertia: 0.2000616258572543
# Minibatch step 172/29916: mean batch inertia: 0.1876357727050781, ewa inertia: 0.19997855659593716
# Minibatch step 173/29916: mean batch inertia: 0.18672572326660156, ewa inertia: 0.19988995881021213
# Minibatch step 174/29916: mean batch inertia: 0.1870489501953125, ewa inertia: 0.19980411415333882
# Minibatch step 175/29916: mean batch inertia: 0.1885089874267578, ewa inertia: 0.19972860401957418
# Minibatch step 176/29916: mean batch inertia: 0.18903680419921876, ewa inertia: 0.1996571272443097
# Minibatch step 177/29916: mean batch inertia: 0.18881243896484376, ewa inertia: 0.19958462837976035
# Minibatch step 178/29916: mean batch inertia: 0.18771017456054687, ewa inertia: 0.19950524533094863
# Minibatch step 179/29916: mean batch inertia: 0.18903791809082032, ewa inertia: 0.19943526919883492
# Minibatch step 180/29916: mean batch inertia: 0.18787071228027344, ewa inertia: 0.1993579578714822
# Minibatch step 181/29916: mean batch inertia: 0.1879766845703125, ewa inertia: 0.19928187183099885
# Minibatch step 182/29916: mean batch inertia: 0.18851409912109374, ewa inertia: 0.19920988716209215
# Minibatch step 183/29916: mean batch inertia: 0.1893033447265625, ewa inertia: 0.19914365998619943
# Minibatch step 184/29916: mean batch inertia: 0.18599632263183594, ewa inertia: 0.19905576746172332
# Minibatch step 185/29916: mean batch inertia: 0.1868349609375, ewa inertia: 0.1989740689772624
# Minibatch step 186/29916: mean batch inertia: 0.18648843383789063, ewa inertia: 0.19889060006165551
# Minibatch step 187/29916: mean batch inertia: 0.18798286437988282, ewa inertia: 0.198817679712877
# Minibatch step 188/29916: mean batch inertia: 0.18786672973632812, ewa inertia: 0.1987444704680765
# Minibatch step 189/29916: mean batch inertia: 0.18629598999023436, ewa inertia: 0.19866124993865686
# Minibatch step 190/29916: mean batch inertia: 0.18831011962890626, ewa inertia: 0.19859205060577423
# Minibatch step 191/29916: mean batch inertia: 0.18783670043945314, ewa inertia: 0.19852014898400372
# Minibatch step 192/29916: mean batch inertia: 0.18640626525878906, ewa inertia: 0.19843916529938974
# Minibatch step 193/29916: mean batch inertia: 0.18716615295410155, ewa inertia: 0.19836380300459405
# Minibatch step 194/29916: mean batch inertia: 0.18766276550292968, ewa inertia: 0.19829226447362128
# Minibatch step 195/29916: mean batch inertia: 0.18615901184082032, ewa inertia: 0.19821115130406763
# Minibatch step 196/29916: mean batch inertia: 0.18721649169921875, ewa inertia: 0.19813764985184357
# Minibatch step 197/29916: mean batch inertia: 0.1865179443359375, ewa inertia: 0.19805996984531943
# Minibatch step 198/29916: mean batch inertia: 0.1872855682373047, ewa inertia: 0.1979879408609309
# Minibatch step 199/29916: mean batch inertia: 0.18770013427734375, ewa inertia: 0.19791916485955652
# Minibatch step 200/29916: mean batch inertia: 0.18879411315917968, ewa inertia: 0.197858162102245
# Minibatch step 201/29916: mean batch inertia: 0.1872039794921875, ewa inertia: 0.19778693680539686
# Minibatch step 202/29916: mean batch inertia: 0.18726235961914062, ewa inertia: 0.1977165779461837
# Minibatch step 203/29916: mean batch inertia: 0.18667601013183593, ewa inertia: 0.19764276958859023
# Minibatch step 204/29916: mean batch inertia: 0.18701557922363282, ewa inertia: 0.1975717247401857
# Minibatch step 205/29916: mean batch inertia: 0.18764485168457032, ewa inertia: 0.19750536165011695
# Minibatch step 206/29916: mean batch inertia: 0.1880339813232422, ewa inertia: 0.19744204361812578
# Minibatch step 207/29916: mean batch inertia: 0.18586441040039062, ewa inertia: 0.19736464487315272
# Minibatch step 208/29916: mean batch inertia: 0.1860028076171875, ewa inertia: 0.19728868876643718
# Minibatch step 209/29916: mean batch inertia: 0.18839907836914063, ewa inertia: 0.19722925998033639
# Minibatch step 210/29916: mean batch inertia: 0.18860260009765625, ewa inertia: 0.19717158906991178
# Minibatch step 211/29916: mean batch inertia: 0.1874986572265625, ewa inertia: 0.19710692362656895
# Minibatch step 212/29916: mean batch inertia: 0.18668777465820313, ewa inertia: 0.19703726957563533
# Minibatch step 213/29916: mean batch inertia: 0.18820660400390626, ewa inertia: 0.1969782348472349
# Minibatch step 214/29916: mean batch inertia: 0.1870181884765625, ewa inertia: 0.19691164998705962
# Minibatch step 215/29916: mean batch inertia: 0.18813873291015626, ewa inertia: 0.19685300131865432
# Minibatch step 216/29916: mean batch inertia: 0.1859539794921875, ewa inertia: 0.1967801392237047
# Minibatch step 217/29916: mean batch inertia: 0.18687197875976563, ewa inertia: 0.19671390123097524
# Minibatch step 218/29916: mean batch inertia: 0.1876510772705078, ewa inertia: 0.19665331447828927
# Minibatch step 219/29916: mean batch inertia: 0.18802450561523437, ewa inertia: 0.19659562920151008
# Minibatch step 220/29916: mean batch inertia: 0.18622233581542968, ewa inertia: 0.1965262817041226
# Minibatch step 221/29916: mean batch inertia: 0.18742778015136718, ewa inertia: 0.19646545643974644
# Minibatch step 222/29916: mean batch inertia: 0.18831915283203124, ewa inertia: 0.19641099680507423
# Minibatch step 223/29916: mean batch inertia: 0.18747491455078125, ewa inertia: 0.19635125734551018
# Minibatch step 224/29916: mean batch inertia: 0.1868685302734375, ewa inertia: 0.19628786345830565
# Minibatch step 225/29916: mean batch inertia: 0.1881656494140625, ewa inertia: 0.19623356486708202
# Minibatch step 226/29916: mean batch inertia: 0.188132080078125, ewa inertia: 0.19617940485498878
# Minibatch step 227/29916: mean batch inertia: 0.18756005859375, ewa inertia: 0.19612178283755552
# Minibatch step 228/29916: mean batch inertia: 0.1871771697998047, ewa inertia: 0.1960619863480337
# Minibatch step 229/29916: mean batch inertia: 0.1875716552734375, ewa inertia: 0.19600522682238447
# Minibatch step 230/29916: mean batch inertia: 0.18788177490234376, ewa inertia: 0.19595091995571876
# Minibatch step 231/29916: mean batch inertia: 0.18669514465332032, ewa inertia: 0.1958890432855319
# Minibatch step 232/29916: mean batch inertia: 0.18829100036621094, ewa inertia: 0.19583824888091161
# Minibatch step 233/29916: mean batch inertia: 0.1862483673095703, ewa inertia: 0.1957741386448985
# Minibatch step 234/29916: mean batch inertia: 0.18794160461425782, ewa inertia: 0.19572177662128545
# Minibatch step 235/29916: mean batch inertia: 0.18809963989257814, ewa inertia: 0.19567082114483184
# Minibatch step 236/29916: mean batch inertia: 0.18792030334472656, ewa inertia: 0.19561900741577876
# Minibatch step 237/29916: mean batch inertia: 0.18782476806640624, ewa inertia: 0.1955669013996081
# Minibatch step 238/29916: mean batch inertia: 0.18674044799804687, ewa inertia: 0.19550789483039002
# Minibatch step 239/29916: mean batch inertia: 0.18771351623535157, ewa inertia: 0.19545578788333484
# Minibatch step 240/29916: mean batch inertia: 0.18738874816894532, ewa inertia: 0.19540185814330946
# Minibatch step 241/29916: mean batch inertia: 0.18697109985351562, ewa inertia: 0.19534549687339103
# Minibatch step 242/29916: mean batch inertia: 0.1873019714355469, ewa inertia: 0.19529172433090847
# Minibatch step 243/29916: mean batch inertia: 0.18901725769042968, ewa inertia: 0.19524977829286985
# Minibatch step 244/29916: mean batch inertia: 0.18793270874023438, ewa inertia: 0.1952008622502207
# Minibatch step 245/29916: mean batch inertia: 0.187624267578125, ewa inertia: 0.1951502112313327
# Minibatch step 246/29916: mean batch inertia: 0.18695622253417968, ewa inertia: 0.1950954328125008
# Minibatch step 247/29916: mean batch inertia: 0.18646482849121093, ewa inertia: 0.19503773553273177
# Minibatch step 248/29916: mean batch inertia: 0.18610845947265625, ewa inertia: 0.19497804157390872
# Minibatch step 249/29916: mean batch inertia: 0.18637481689453125, ewa inertia: 0.1949205273324068
# Minibatch step 250/29916: mean batch inertia: 0.18816452026367186, ewa inertia: 0.19487536210231918
# Minibatch step 251/29916: mean batch inertia: 0.1865181884765625, ewa inertia: 0.1948194927602878
# Minibatch step 252/29916: mean batch inertia: 0.1877435302734375, ewa inertia: 0.19477218856558245
# Minibatch step 253/29916: mean batch inertia: 0.18607684326171875, ewa inertia: 0.19471405847966858
# Minibatch step 254/29916: mean batch inertia: 0.186901611328125, ewa inertia: 0.1946618307407753
# Minibatch step 255/29916: mean batch inertia: 0.18807992553710937, ewa inertia: 0.194617829415745
# Minibatch step 256/29916: mean batch inertia: 0.18697177124023437, ewa inertia: 0.19456671401973563
# Minibatch step 257/29916: mean batch inertia: 0.18746983337402343, ewa inertia: 0.1945192699830425
# Minibatch step 258/29916: mean batch inertia: 0.18652719116210936, ewa inertia: 0.19446584137126732
# Minibatch step 259/29916: mean batch inertia: 0.18620474243164062, ewa inertia: 0.19441061430732423
# Minibatch step 260/29916: mean batch inertia: 0.18604815673828126, ewa inertia: 0.19435470964109736
# Minibatch step 261/29916: mean batch inertia: 0.18749049377441407, ewa inertia: 0.19430882101400804
# Minibatch step 262/29916: mean batch inertia: 0.18707366943359374, ewa inertia: 0.19426045260904284
# Minibatch step 263/29916: mean batch inertia: 0.1877538757324219, ewa inertia: 0.1942169548686282
# Minibatch step 264/29916: mean batch inertia: 0.18667063903808595, ewa inertia: 0.19416650626972462
# Minibatch step 265/29916: mean batch inertia: 0.1838898162841797, ewa inertia: 0.19409780458498477
# Minibatch step 266/29916: mean batch inertia: 0.18845834350585938, ewa inertia: 0.19406010368345855
# Minibatch step 267/29916: mean batch inertia: 0.18612152099609375, ewa inertia: 0.19400703270381087
# Minibatch step 268/29916: mean batch inertia: 0.18882177734375, ewa inertia: 0.19397236825645053
# Minibatch step 269/29916: mean batch inertia: 0.1879210510253906, ewa inertia: 0.19393191401590676
# Minibatch step 270/29916: mean batch inertia: 0.18758676147460937, ewa inertia: 0.19388949542878078
# Minibatch step 271/29916: mean batch inertia: 0.18751202392578126, ewa inertia: 0.19384686078306773
# Minibatch step 272/29916: mean batch inertia: 0.1862453155517578, ewa inertia: 0.19379604296480604
# Minibatch step 273/29916: mean batch inertia: 0.18644749450683593, ewa inertia: 0.19374691647951114
# Minibatch step 274/29916: mean batch inertia: 0.18820904541015626, ewa inertia: 0.19370989472709166
# Minibatch step 275/29916: mean batch inertia: 0.18642730712890626, ewa inertia: 0.19366120920305963
# Minibatch step 276/29916: mean batch inertia: 0.1885602264404297, ewa inertia: 0.19362710813451375
# Minibatch step 277/29916: mean batch inertia: 0.18704083251953124, ewa inertia: 0.19358307759242807
# Minibatch step 278/29916: mean batch inertia: 0.18791061401367187, ewa inertia: 0.19354515606272987
# Minibatch step 279/29916: mean batch inertia: 0.18580026245117187, ewa inertia: 0.19349337993247845
# Minibatch step 280/29916: mean batch inertia: 0.18593087768554686, ewa inertia: 0.193442823124212
# Minibatch step 281/29916: mean batch inertia: 0.188864990234375, ewa inertia: 0.19341221941499903
# Minibatch step 282/29916: mean batch inertia: 0.1877050323486328, ewa inertia: 0.19337406575198726
# Minibatch step 283/29916: mean batch inertia: 0.18696858215332032, ewa inertia: 0.1933312438399299
# Minibatch step 284/29916: mean batch inertia: 0.1872727508544922, ewa inertia: 0.19329074162806306
# Minibatch step 285/29916: mean batch inertia: 0.187194091796875, ewa inertia: 0.19324998433021126
# Minibatch step 286/29916: mean batch inertia: 0.18530340576171875, ewa inertia: 0.19319685989653262
# Minibatch step 287/29916: mean batch inertia: 0.18786045837402343, ewa inertia: 0.19316118500748172
# Minibatch step 288/29916: mean batch inertia: 0.18813899230957032, ewa inertia: 0.19312761066594566
# Minibatch step 289/29916: mean batch inertia: 0.18758132934570312, ewa inertia: 0.19309053268935225
# Minibatch step 290/29916: mean batch inertia: 0.18769277954101563, ewa inertia: 0.19305444765267
# Minibatch step 291/29916: mean batch inertia: 0.1867454071044922, ewa inertia: 0.1930122704812888
# Minibatch step 292/29916: mean batch inertia: 0.18811550903320312, ewa inertia: 0.1929795346722174
# Minibatch step 293/29916: mean batch inertia: 0.18701063537597656, ewa inertia: 0.19293963141170542
# Minibatch step 294/29916: mean batch inertia: 0.18752543640136718, ewa inertia: 0.19290343645795635
# Minibatch step 295/29916: mean batch inertia: 0.1862979736328125, ewa inertia: 0.19285927764561384
# Minibatch step 296/29916: mean batch inertia: 0.1873074493408203, ewa inertia: 0.19282216258634258
# Minibatch step 297/29916: mean batch inertia: 0.18743601989746095, ewa inertia: 0.1927861551678551
# Minibatch step 298/29916: mean batch inertia: 0.18590135192871093, ewa inertia: 0.19274012891014988
# Minibatch step 299/29916: mean batch inertia: 0.18649200439453126, ewa inertia: 0.19269835897437373
# Minibatch step 300/29916: mean batch inertia: 0.18659646606445313, ewa inertia: 0.192657566625514
# Minibatch step 301/29916: mean batch inertia: 0.18599087524414062, ewa inertia: 0.1926129984882845
# Minibatch step 302/29916: mean batch inertia: 0.18572621154785157, ewa inertia: 0.19256695896914772
# Minibatch step 303/29916: mean batch inertia: 0.18549446105957032, ewa inertia: 0.19251967793581984
# Minibatch step 304/29916: mean batch inertia: 0.18859303283691406, ewa inertia: 0.1924934275444925
# Minibatch step 305/29916: mean batch inertia: 0.18570831298828125, ewa inertia: 0.1924480677251518
# Minibatch step 306/29916: mean batch inertia: 0.1874086151123047, ewa inertia: 0.19241437799770492
# Minibatch step 307/29916: mean batch inertia: 0.18799526977539063, ewa inertia: 0.1923848353939728
# Minibatch step 308/29916: mean batch inertia: 0.18813101196289062, ewa inertia: 0.192356397751433
# Minibatch step 309/29916: mean batch inertia: 0.1889447784423828, ewa inertia: 0.19233359040835343
# Minibatch step 310/29916: mean batch inertia: 0.18618255615234375, ewa inertia: 0.19229246953997317
# Minibatch step 311/29916: mean batch inertia: 0.18869259643554687, ewa inertia: 0.19226840368341122
# Minibatch step 312/29916: mean batch inertia: 0.186558837890625, ewa inertia: 0.19223023411814757
# Minibatch step 313/29916: mean batch inertia: 0.18609225463867188, ewa inertia: 0.19218920052350458
# Minibatch step 314/29916: mean batch inertia: 0.1874361572265625, ewa inertia: 0.19215742549841375
# Minibatch step 315/29916: mean batch inertia: 0.18788604736328124, ewa inertia: 0.19212887049924016
# Minibatch step 316/29916: mean batch inertia: 0.18598155212402342, ewa inertia: 0.19208777447225056
# Minibatch step 317/29916: mean batch inertia: 0.1864386291503906, ewa inertia: 0.19205000882966547
# Minibatch step 318/29916: mean batch inertia: 0.18532015991210937, ewa inertia: 0.19200501847194026
# Minibatch step 319/29916: mean batch inertia: 0.18515478515625, ewa inertia: 0.19195922332094215
# Minibatch step 320/29916: mean batch inertia: 0.18772843933105468, ewa inertia: 0.1919309397015779
# Minibatch step 321/29916: mean batch inertia: 0.18765066528320312, ewa inertia: 0.19190232522900894
# Minibatch step 322/29916: mean batch inertia: 0.1863394775390625, ewa inertia: 0.19186513650299036
# Minibatch step 323/29916: mean batch inertia: 0.18703408813476563, ewa inertia: 0.19183283999872452
# Minibatch step 324/29916: mean batch inertia: 0.18659844970703124, ewa inertia: 0.19179784707472552
# Minibatch step 325/29916: mean batch inertia: 0.1863966064453125, ewa inertia: 0.19176173872354943
# Minibatch step 326/29916: mean batch inertia: 0.1864731903076172, ewa inertia: 0.19172638374188572
# Minibatch step 327/29916: mean batch inertia: 0.18599603271484375, ewa inertia: 0.1916880752232613
# Minibatch step 328/29916: mean batch inertia: 0.18583285522460938, ewa inertia: 0.19164893193111224
# Minibatch step 329/29916: mean batch inertia: 0.18731446838378907, ewa inertia: 0.19161995519360595
# Minibatch step 330/29916: mean batch inertia: 0.18502523803710938, ewa inertia: 0.19157586821816236
# Minibatch step 331/29916: mean batch inertia: 0.18804791259765624, ewa inertia: 0.19155228314406195
# Minibatch step 332/29916: mean batch inertia: 0.18659953308105467, ewa inertia: 0.1915191730401372
# Minibatch step 333/29916: mean batch inertia: 0.18708062744140624, ewa inertia: 0.19148950049373786
# Minibatch step 334/29916: mean batch inertia: 0.18889688110351563, ewa inertia: 0.1914721683254767
# Minibatch step 335/29916: mean batch inertia: 0.18587255859375, ewa inertia: 0.19143473383801077
# Minibatch step 336/29916: mean batch inertia: 0.18556465148925783, ewa inertia: 0.19139549118814117
# Minibatch step 337/29916: mean batch inertia: 0.18789414978027344, ewa inertia: 0.19137208403526332
# Minibatch step 338/29916: mean batch inertia: 0.1873226318359375, ewa inertia: 0.1913450126544239
# Minibatch step 339/29916: mean batch inertia: 0.18600398254394532, ewa inertia: 0.19130930682235617
# Minibatch step 340/29916: mean batch inertia: 0.18698631286621092, ewa inertia: 0.19128040676131267
# Minibatch step 341/29916: mean batch inertia: 0.1860433349609375, ewa inertia: 0.19124539591090312
# Minibatch step 342/29916: mean batch inertia: 0.1878182830810547, ewa inertia: 0.19122248499060335
# Minibatch step 343/29916: mean batch inertia: 0.1882138671875, ewa inertia: 0.19120237179149913
# Minibatch step 344/29916: mean batch inertia: 0.18625584411621093, ewa inertia: 0.19116930328545462
# Minibatch step 345/29916: mean batch inertia: 0.18800228881835937, ewa inertia: 0.1911481311736374
# Minibatch step 346/29916: mean batch inertia: 0.18842828369140624, ewa inertia: 0.19112994846066975
# Minibatch step 347/29916: mean batch inertia: 0.18879609680175782, ewa inertia: 0.19111434620535936
# Minibatch step 348/29916: mean batch inertia: 0.18605484008789064, ewa inertia: 0.19108052241630757
# Minibatch step 349/29916: mean batch inertia: 0.185965087890625, ewa inertia: 0.19104632473489605
# Minibatch step 350/29916: mean batch inertia: 0.18812882995605468, ewa inertia: 0.191026820711051
# Minibatch step 351/29916: mean batch inertia: 0.18910093688964844, ewa inertia: 0.1910139458006149
# Minibatch step 352/29916: mean batch inertia: 0.18736358642578124, ewa inertia: 0.19098954243345
# Minibatch step 353/29916: mean batch inertia: 0.18638424682617188, ewa inertia: 0.19095875513059374
# Minibatch step 354/29916: mean batch inertia: 0.1880672302246094, ewa inertia: 0.19093942472043368
# Minibatch step 355/29916: mean batch inertia: 0.18760137939453125, ewa inertia: 0.1909171092338373
# Minibatch step 356/29916: mean batch inertia: 0.18567605590820313, ewa inertia: 0.1908820717661518
# Minibatch step 357/29916: mean batch inertia: 0.18640121459960937, ewa inertia: 0.19085211635863703
# Minibatch step 358/29916: mean batch inertia: 0.1867379913330078, ewa inertia: 0.19082461262729078
# Minibatch step 359/29916: mean batch inertia: 0.18577201843261718, ewa inertia: 0.19079083504579625
# Minibatch step 360/29916: mean batch inertia: 0.18697830200195312, ewa inertia: 0.19076534751590027
# Minibatch step 361/29916: mean batch inertia: 0.18759709167480468, ewa inertia: 0.1907441671052548
# Minibatch step 362/29916: mean batch inertia: 0.18690522766113282, ewa inertia: 0.19071850304340254
# Minibatch step 363/29916: mean batch inertia: 0.18649452209472656, ewa inertia: 0.1906902649037008
# Minibatch step 364/29916: mean batch inertia: 0.18813444519042968, ewa inertia: 0.19067317874848544
# Minibatch step 365/29916: mean batch inertia: 0.18867733764648437, ewa inertia: 0.19065983615993082
# Minibatch step 366/29916: mean batch inertia: 0.18697415161132813, ewa inertia: 0.19063519663706258
# Minibatch step 367/29916: mean batch inertia: 0.18748782348632811, ewa inertia: 0.19061415583129102
# Minibatch step 368/29916: mean batch inertia: 0.18817245483398437, ewa inertia: 0.19059783258203647
# Minibatch step 369/29916: mean batch inertia: 0.18698959350585936, ewa inertia: 0.19057371079731528
# Minibatch step 370/29916: mean batch inertia: 0.18763172912597656, ewa inertia: 0.19055404307379933
# Minibatch step 371/29916: mean batch inertia: 0.18723817443847657, ewa inertia: 0.19053187584272172
# Minibatch step 372/29916: mean batch inertia: 0.18877108764648437, ewa inertia: 0.19052010462886573
# Minibatch step 373/29916: mean batch inertia: 0.18667623901367186, ewa inertia: 0.19049440763459533
# Minibatch step 374/29916: mean batch inertia: 0.186962158203125, ewa inertia: 0.19047079385552787
# Minibatch step 375/29916: mean batch inertia: 0.187856689453125, ewa inertia: 0.19045331805575347
# Minibatch step 376/29916: mean batch inertia: 0.18611346435546874, ewa inertia: 0.19042430528401924
# Minibatch step 377/29916: mean batch inertia: 0.18582884216308593, ewa inertia: 0.1903935837132594
# Minibatch step 378/29916: mean batch inertia: 0.18673431396484375, ewa inertia: 0.19036912077850246
# Minibatch step 379/29916: mean batch inertia: 0.18422938537597655, ewa inertia: 0.19032807544517005
# Minibatch step 380/29916: mean batch inertia: 0.187847412109375, ewa inertia: 0.19031149172505382
# Minibatch step 381/29916: mean batch inertia: 0.18881314086914064, ewa inertia: 0.1903014749562034
# Minibatch step 382/29916: mean batch inertia: 0.18646681213378907, ewa inertia: 0.19027583948440463
# Minibatch step 383/29916: mean batch inertia: 0.1887983856201172, ewa inertia: 0.19026596241603486
# Minibatch step 384/29916: mean batch inertia: 0.18677685546875, ewa inertia: 0.19024263705292152
# Minibatch step 385/29916: mean batch inertia: 0.1883333282470703, ewa inertia: 0.19022987294970978
# Minibatch step 386/29916: mean batch inertia: 0.1853470458984375, ewa inertia: 0.19019723029480948
# Minibatch step 387/29916: mean batch inertia: 0.18636138916015624, ewa inertia: 0.19017158694576267
# Minibatch step 388/29916: mean batch inertia: 0.18642825317382813, ewa inertia: 0.19014656202654867
# Minibatch step 389/29916: mean batch inertia: 0.188839111328125, ewa inertia: 0.19013782146262953
# Minibatch step 390/29916: mean batch inertia: 0.1870618896484375, ewa inertia: 0.19011725825618103
# Minibatch step 391/29916: mean batch inertia: 0.1872196044921875, ewa inertia: 0.19009788687340512
# Minibatch step 392/29916: mean batch inertia: 0.18742611694335937, ewa inertia: 0.19008002556828746
# Minibatch step 393/29916: mean batch inertia: 0.18689254760742188, ewa inertia: 0.19005871665400761
# Minibatch step 394/29916: mean batch inertia: 0.1850760955810547, ewa inertia: 0.1900254068565326
# Minibatch step 395/29916: mean batch inertia: 0.1857478485107422, ewa inertia: 0.18999681054144066
# Minibatch step 396/29916: mean batch inertia: 0.18505941772460938, ewa inertia: 0.18996380310371355
# Minibatch step 397/29916: mean batch inertia: 0.1869154052734375, ewa inertia: 0.1899434239673387
# Minibatch step 398/29916: mean batch inertia: 0.18737876892089844, ewa inertia: 0.18992627874619117
# Minibatch step 399/29916: mean batch inertia: 0.18556367492675782, ewa inertia: 0.18989711388545594
# Minibatch step 400/29916: mean batch inertia: 0.1854207763671875, ewa inertia: 0.18986718869267483
# Minibatch step 401/29916: mean batch inertia: 0.1866573944091797, ewa inertia: 0.18984573058940862
# Minibatch step 402/29916: mean batch inertia: 0.18686782836914062, ewa inertia: 0.18982582272998982
# Minibatch step 403/29916: mean batch inertia: 0.1871998748779297, ewa inertia: 0.18980826775443552
# Minibatch step 404/29916: mean batch inertia: 0.1869800567626953, ewa inertia: 0.1897893606101891
# Minibatch step 405/29916: mean batch inertia: 0.1849181365966797, ewa inertia: 0.18975679552386812
# Minibatch step 406/29916: mean batch inertia: 0.1854627685546875, ewa inertia: 0.18972808911280425
# Minibatch step 407/29916: mean batch inertia: 0.18646267700195313, ewa inertia: 0.18970625919347214
# Minibatch step 408/29916: mean batch inertia: 0.18575946044921876, ewa inertia: 0.18967987407107956
# Minibatch step 409/29916: mean batch inertia: 0.18741969299316405, ewa inertia: 0.1896647643180279
# Minibatch step 410/29916: mean batch inertia: 0.18824952697753905, ewa inertia: 0.1896553031793018
# Minibatch step 411/29916: mean batch inertia: 0.18829696655273437, ewa inertia: 0.18964622243298948
# Minibatch step 412/29916: mean batch inertia: 0.18650645446777345, ewa inertia: 0.18962523246937218
# Minibatch step 413/29916: mean batch inertia: 0.18762979125976562, ewa inertia: 0.18961189255417651
# Minibatch step 414/29916: mean batch inertia: 0.1864696044921875, ewa inertia: 0.1895908857432189
# Minibatch step 415/29916: mean batch inertia: 0.18914085388183594, ewa inertia: 0.18958787719210882
# Minibatch step 416/29916: mean batch inertia: 0.18736859130859376, ewa inertia: 0.18957304083143905
# Minibatch step 417/29916: mean batch inertia: 0.18717271423339843, ewa inertia: 0.18955699417814473
# Minibatch step 418/29916: mean batch inertia: 0.1877403106689453, ewa inertia: 0.18954484929317722
# Minibatch step 419/29916: mean batch inertia: 0.18467816162109374, ewa inertia: 0.1895123145331869
# Minibatch step 420/29916: mean batch inertia: 0.18808277893066405, ewa inertia: 0.1895027578077795
# Minibatch step 421/29916: mean batch inertia: 0.1849165802001953, ewa inertia: 0.1894720983124945
# Minibatch step 422/29916: mean batch inertia: 0.18698760986328125, ewa inertia: 0.18945548902074613
# Minibatch step 423/29916: mean batch inertia: 0.1851958465576172, ewa inertia: 0.18942701247683774
# Minibatch step 424/29916: mean batch inertia: 0.18739083862304687, ewa inertia: 0.1894134002559402
# Minibatch step 425/29916: mean batch inertia: 0.1878636474609375, ewa inertia: 0.1894030398550624
# Minibatch step 426/29916: mean batch inertia: 0.18604310607910157, ewa inertia: 0.1893805780398916
# Minibatch step 427/29916: mean batch inertia: 0.1859087829589844, ewa inertia: 0.18935736840999468
# Minibatch step 428/29916: mean batch inertia: 0.18674169921875, ewa inertia: 0.18933988214930048
# Minibatch step 429/29916: mean batch inertia: 0.18739486694335938, ewa inertia: 0.18932687934181278
# Minibatch step 430/29916: mean batch inertia: 0.185825439453125, ewa inertia: 0.18930347153057137
# Minibatch step 431/29916: mean batch inertia: 0.185456298828125, ewa inertia: 0.18927775242777514
# Minibatch step 432/29916: mean batch inertia: 0.18744142150878906, ewa inertia: 0.18926547619602624
# Minibatch step 433/29916: mean batch inertia: 0.18649830627441405, ewa inertia: 0.18924697712328553
# Minibatch step 434/29916: mean batch inertia: 0.18775639343261719, ewa inertia: 0.18923701227945558
# Minibatch step 435/29916: mean batch inertia: 0.18607272338867187, ewa inertia: 0.18921585838864968
# Minibatch step 436/29916: mean batch inertia: 0.18494497680664063, ewa inertia: 0.18918730670903094
# Minibatch step 437/29916: mean batch inertia: 0.18737498474121095, ewa inertia: 0.18917519098182156
# Minibatch step 438/29916: mean batch inertia: 0.18632243347167968, ewa inertia: 0.18915611973929342
# Minibatch step 439/29916: mean batch inertia: 0.1864878234863281, ewa inertia: 0.18913828165638719
# Minibatch step 440/29916: mean batch inertia: 0.1862878875732422, ewa inertia: 0.18911922621383126
# Minibatch step 441/29916: mean batch inertia: 0.18537045288085938, ewa inertia: 0.18909416493008666
# Minibatch step 442/29916: mean batch inertia: 0.1862825469970703, ewa inertia: 0.18907536871368677
# Minibatch step 443/29916: mean batch inertia: 0.18626165771484374, ewa inertia: 0.189056558504732
# Minibatch step 444/29916: mean batch inertia: 0.18610057067871094, ewa inertia: 0.18903679714732957
# Minibatch step 445/29916: mean batch inertia: 0.18650178527832031, ewa inertia: 0.1890198500966273
# Minibatch step 446/29916: mean batch inertia: 0.18577430725097657, ewa inertia: 0.18899815300722347
# Minibatch step 447/29916: mean batch inertia: 0.1885137939453125, ewa inertia: 0.1889949149720566
# Minibatch step 448/29916: mean batch inertia: 0.1856060791015625, ewa inertia: 0.18897225994072478
# Minibatch step 449/29916: mean batch inertia: 0.18750541687011718, ewa inertia: 0.1889624538075884
# Minibatch step 450/29916: mean batch inertia: 0.18649070739746093, ewa inertia: 0.18894592969886617
# Minibatch step 451/29916: mean batch inertia: 0.18619303894042968, ewa inertia: 0.18892752608512717
# Minibatch step 452/29916: mean batch inertia: 0.18774856567382814, ewa inertia: 0.18891964450393597
# Minibatch step 453/29916: mean batch inertia: 0.186911865234375, ewa inertia: 0.1889062221063937
# Minibatch step 454/29916: mean batch inertia: 0.18885404968261718, ewa inertia: 0.18890587332352535
# Minibatch step 455/29916: mean batch inertia: 0.18642437744140625, ewa inertia: 0.1888892840376739
# Minibatch step 456/29916: mean batch inertia: 0.18894248962402344, ewa inertia: 0.18888963972743636
# Minibatch step 457/29916: mean batch inertia: 0.18752816772460937, ewa inertia: 0.18888053802051985
# Minibatch step 458/29916: mean batch inertia: 0.18871322631835938, ewa inertia: 0.1888794195090311
# Minibatch step 459/29916: mean batch inertia: 0.18784201049804689, ewa inertia: 0.1888724842266669
# Minibatch step 460/29916: mean batch inertia: 0.18738674926757812, ewa inertia: 0.18886255179755693
# Minibatch step 461/29916: mean batch inertia: 0.18668165588378907, ewa inertia: 0.18884797208135173
# Minibatch step 462/29916: mean batch inertia: 0.18485720825195312, ewa inertia: 0.18882129304375653
# Minibatch step 463/29916: mean batch inertia: 0.18730459594726562, ewa inertia: 0.18881115362669565
# Minibatch step 464/29916: mean batch inertia: 0.18545976257324218, ewa inertia: 0.1887887489212975
# ...
# Minibatch step 683/29916: mean batch inertia: 0.1855, ewa inertia: 0.18707293780602255
# Minibatch step 684/29916: mean batch inertia: 0.18645486450195312, ewa inertia: 0.18706880586496544
# Minibatch step 685/29916: mean batch inertia: 0.18580253601074218, ewa inertia: 0.18706034060305302
# Minibatch step 686/29916: mean batch inertia: 0.18481434631347657, ewa inertia: 0.1870453256914592
# Minibatch step 687/29916: mean batch inertia: 0.18672283935546874, ewa inertia: 0.18704316980715993
# Minibatch step 688/29916: mean batch inertia: 0.18538169860839843, ewa inertia: 0.18703206254687843
# Minibatch step 689/29916: mean batch inertia: 0.18446868896484375, ewa inertia: 0.18701492589257135
# Minibatch step 690/29916: mean batch inertia: 0.18822665405273437, ewa inertia: 0.18702302653257966
# Minibatch step 691/29916: mean batch inertia: 0.18635206604003907, ewa inertia: 0.18701854103031226
# Minibatch step 692/29916: mean batch inertia: 0.186152099609375, ewa inertia: 0.18701274869976317
# Minibatch step 693/29916: mean batch inertia: 0.18531881713867188, ewa inertia: 0.18700142443560372
# Minibatch step 694/29916: mean batch inertia: 0.1858734130859375, ewa inertia: 0.18699388345886542
# Minibatch step 695/29916: mean batch inertia: 0.18489488220214845, ewa inertia: 0.18697985122447766
# Minibatch step 696/29916: mean batch inertia: 0.18838177490234376, ewa inertia: 0.18698922335876228
# Minibatch step 697/29916: mean batch inertia: 0.18530215454101562, ewa inertia: 0.18697794497338582
# Minibatch step 698/29916: mean batch inertia: 0.18899716186523438, ewa inertia: 0.18699144383367255
# Minibatch step 699/29916: mean batch inertia: 0.18715667724609375, ewa inertia: 0.18699254845138746
# Minibatch step 700/29916: mean batch inertia: 0.18504150390625, ewa inertia: 0.18697950533658667
# Minibatch step 701/29916: mean batch inertia: 0.1872933349609375, ewa inertia: 0.1869816033490736
# Minibatch step 702/29916: mean batch inertia: 0.18593473815917969, ewa inertia: 0.18697460485030187
# Minibatch step 703/29916: mean batch inertia: 0.18634710693359374, ewa inertia: 0.18697040990386393
# Minibatch step 704/29916: mean batch inertia: 0.18598641967773438, ewa inertia: 0.18696383173653594
# Minibatch step 705/29916: mean batch inertia: 0.18552574157714843, ewa inertia: 0.1869542178222409
# Minibatch step 706/29916: mean batch inertia: 0.1862467041015625, ewa inertia: 0.18694948795448624
# Minibatch step 707/29916: mean batch inertia: 0.18684465026855468, ewa inertia: 0.18694878709402846
# Minibatch step 708/29916: mean batch inertia: 0.18750270080566406, ewa inertia: 0.1869524901156476
# Minibatch step 709/29916: mean batch inertia: 0.18713619995117187, ewa inertia: 0.18695371825186866
# Minibatch step 710/29916: mean batch inertia: 0.18754522705078125, ewa inertia: 0.18695767260400742
# Minibatch step 711/29916: mean batch inertia: 0.18496005249023437, ewa inertia: 0.18694431812241077
# Minibatch step 712/29916: mean batch inertia: 0.18593086242675783, ewa inertia: 0.18693754297264967
# Minibatch step 713/29916: mean batch inertia: 0.18837985229492188, ewa inertia: 0.1869471850928747
# Minibatch step 714/29916: mean batch inertia: 0.18641714477539062, ewa inertia: 0.18694364166956987
# Minibatch step 715/29916: mean batch inertia: 0.18624050903320313, ewa inertia: 0.18693894109022163
# Minibatch step 716/29916: mean batch inertia: 0.18708885192871094, ewa inertia: 0.1869399432735296
# Minibatch step 717/29916: mean batch inertia: 0.18712167358398438, ewa inertia: 0.186941158176238
# Minibatch step 718/29916: mean batch inertia: 0.18696340942382814, ewa inertia: 0.18694130693018496
# Minibatch step 719/29916: mean batch inertia: 0.18679937744140626, ewa inertia: 0.18694035810376253
# Minibatch step 720/29916: mean batch inertia: 0.18621371459960936, ewa inertia: 0.1869355003496597
# Minibatch step 721/29916: mean batch inertia: 0.18481193542480467, ewa inertia: 0.18692130390234085
# Minibatch step 722/29916: mean batch inertia: 0.18665879821777343, ewa inertia: 0.18691954900044064
# Minibatch step 723/29916: mean batch inertia: 0.1862164306640625, ewa inertia: 0.18691484851669066
# Minibatch step 724/29916: mean batch inertia: 0.18689813232421876, ewa inertia: 0.1869147367656709
# Minibatch step 725/29916: mean batch inertia: 0.1860539093017578, ewa inertia: 0.18690898196552375
# Minibatch step 726/29916: mean batch inertia: 0.18555032348632813, ewa inertia: 0.1868998990675636
# Minibatch step 727/29916: mean batch inertia: 0.1869332733154297, ewa inertia: 0.1869001221809453
# Minibatch step 728/29916: mean batch inertia: 0.186557373046875, ewa inertia: 0.18689783083587339
# Minibatch step 729/29916: mean batch inertia: 0.1849337921142578, ewa inertia: 0.1868847008524586
# Minibatch step 730/29916: mean batch inertia: 0.18659451293945312, ewa inertia: 0.18688276088944106
# Minibatch step 731/29916: mean batch inertia: 0.18537989807128907, ewa inertia: 0.18687271395723962
# Minibatch step 732/29916: mean batch inertia: 0.18665536499023438, ewa inertia: 0.18687126093683804
# Minibatch step 733/29916: mean batch inertia: 0.1870403289794922, ewa inertia: 0.18687239118980686
# Minibatch step 734/29916: mean batch inertia: 0.1869885711669922, ewa inertia: 0.1868731678757025
# Minibatch step 735/29916: mean batch inertia: 0.187867431640625, ewa inertia: 0.18687981472364884
# Minibatch step 736/29916: mean batch inertia: 0.18697177124023437, ewa inertia: 0.1868804294709674
# Minibatch step 737/29916: mean batch inertia: 0.1861806182861328, ewa inertia: 0.186875751096173
# Minibatch step 738/29916: mean batch inertia: 0.18557095336914062, ewa inertia: 0.18686702826788704
# Minibatch step 739/29916: mean batch inertia: 0.18805438232421876, ewa inertia: 0.18687496596223876
# Minibatch step 740/29916: mean batch inertia: 0.1875547637939453, ewa inertia: 0.18687951054384883
# Minibatch step 741/29916: mean batch inertia: 0.18684796142578125, ewa inertia: 0.18687929963181718
# Minibatch step 742/29916: mean batch inertia: 0.1864977264404297, ewa inertia: 0.18687674874032031
# Minibatch step 743/29916: mean batch inertia: 0.1850587158203125, ewa inertia: 0.18686459483427734
# Minibatch step 744/29916: mean batch inertia: 0.18576358032226561, ewa inertia: 0.18685723433668477
# Minibatch step 745/29916: mean batch inertia: 0.18632716369628907, ewa inertia: 0.18685369071066535
# Minibatch step 746/29916: mean batch inertia: 0.1873487548828125, ewa inertia: 0.18685700031159022
# Minibatch step 747/29916: mean batch inertia: 0.1864075927734375, ewa inertia: 0.1868539959342032
# Minibatch step 748/29916: mean batch inertia: 0.18596029663085936, ewa inertia: 0.1868480213793731
# Minibatch step 749/29916: mean batch inertia: 0.186258056640625, ewa inertia: 0.18684407734957886
# Minibatch step 750/29916: mean batch inertia: 0.18549261474609374, ewa inertia: 0.1868350425574568
# Minibatch step 751/29916: mean batch inertia: 0.18717164611816406, ewa inertia: 0.18683729281816747
# Minibatch step 752/29916: mean batch inertia: 0.18631878662109375, ewa inertia: 0.186833826502716
# Minibatch step 753/29916: mean batch inertia: 0.187424560546875, ewa inertia: 0.18683777567546753
# Minibatch step 754/29916: mean batch inertia: 0.1870615234375, ewa inertia: 0.18683927147306675
# Minibatch step 755/29916: mean batch inertia: 0.18788809204101561, ewa inertia: 0.18684628304392362
# Minibatch step 756/29916: mean batch inertia: 0.184698486328125, ewa inertia: 0.1868319246023377
# Minibatch step 757/29916: mean batch inertia: 0.18670652770996093, ewa inertia: 0.1868310862995593
# Minibatch step 758/29916: mean batch inertia: 0.18654888916015624, ewa inertia: 0.18682919975642792
# Minibatch step 759/29916: mean batch inertia: 0.18696405029296875, ewa inertia: 0.18683010125866856
# Minibatch step 760/29916: mean batch inertia: 0.18616220092773436, ewa inertia: 0.1868256362141807
# Minibatch step 761/29916: mean batch inertia: 0.18676353454589845, ewa inertia: 0.18682522105236865
# Minibatch step 762/29916: mean batch inertia: 0.18718148803710938, ewa inertia: 0.18682760276691907
# Minibatch step 763/29916: mean batch inertia: 0.18646665954589844, ewa inertia: 0.18682518979081347
# Minibatch step 764/29916: mean batch inertia: 0.18464344787597656, ewa inertia: 0.18681060441892547
# Minibatch step 765/29916: mean batch inertia: 0.18669430541992188, ewa inertia: 0.18680982693734566
# Minibatch step 766/29916: mean batch inertia: 0.187611083984375, ewa inertia: 0.186815183497592
# Minibatch step 767/29916: mean batch inertia: 0.18406202697753907, ewa inertia: 0.18679677810718456
# Minibatch step 768/29916: mean batch inertia: 0.18705136108398437, ewa inertia: 0.18679848004423208
# Minibatch step 769/29916: mean batch inertia: 0.18609619140625, ewa inertia: 0.18679378510717834
# Minibatch step 770/29916: mean batch inertia: 0.18541622924804688, ewa inertia: 0.1867845758765332
# Minibatch step 771/29916: mean batch inertia: 0.18613308715820312, ewa inertia: 0.18678022054688898
# Minibatch step 772/29916: mean batch inertia: 0.18639944458007812, ewa inertia: 0.1867776749849945
# Minibatch step 773/29916: mean batch inertia: 0.18566740417480468, ewa inertia: 0.18677025260723623
# Minibatch step 774/29916: mean batch inertia: 0.18616993713378907, ewa inertia: 0.18676623938075385
# Minibatch step 775/29916: mean batch inertia: 0.1877954864501953, ewa inertia: 0.1867731200989407
# Minibatch step 776/29916: mean batch inertia: 0.18780809020996095, ewa inertia: 0.1867800390767811
# Minibatch step 777/29916: mean batch inertia: 0.18573902893066407, ewa inertia: 0.18677307972012344
# Minibatch step 778/29916: mean batch inertia: 0.18711647033691406, ewa inertia: 0.1867753753536329
# Minibatch step 779/29916: mean batch inertia: 0.18583685302734376, ewa inertia: 0.18676910114811798
# Minibatch step 780/29916: mean batch inertia: 0.18625253295898436, ewa inertia: 0.18676564778862903
# Minibatch step 781/29916: mean batch inertia: 0.18569754028320312, ewa inertia: 0.1867585072808187
# Minibatch step 782/29916: mean batch inertia: 0.18526513671875, ewa inertia: 0.18674852380620777
# Minibatch step 783/29916: mean batch inertia: 0.18698155212402343, ewa inertia: 0.18675008164613954
# Minibatch step 784/29916: mean batch inertia: 0.18755807495117188, ewa inertia: 0.1867554832395896
# Minibatch step 785/29916: mean batch inertia: 0.18751937866210938, ewa inertia: 0.18676059003006065
# Minibatch step 786/29916: mean batch inertia: 0.18685342407226563, ewa inertia: 0.1867612106438098
# Minibatch step 787/29916: mean batch inertia: 0.18521299743652345, ewa inertia: 0.18675086053537734
# Minibatch step 788/29916: mean batch inertia: 0.18570448303222656, ewa inertia: 0.18674386529688697
# Minibatch step 789/29916: mean batch inertia: 0.18618818664550782, ewa inertia: 0.18674015047630005
# Minibatch step 790/29916: mean batch inertia: 0.18735342407226563, ewa inertia: 0.18674425033036868
# Minibatch step 791/29916: mean batch inertia: 0.18391305541992187, ewa inertia: 0.18672532323804145
# Minibatch step 792/29916: mean batch inertia: 0.18651907348632812, ewa inertia: 0.1867239444180673
# Minibatch step 793/29916: mean batch inertia: 0.18514891052246094, ewa inertia: 0.18671341500808192
# Minibatch step 794/29916: mean batch inertia: 0.18592195129394531, ewa inertia: 0.1867081239181835
# Minibatch step 795/29916: mean batch inertia: 0.1863316192626953, ewa inertia: 0.18670560691084154
# Minibatch step 796/29916: mean batch inertia: 0.18667860412597656, ewa inertia: 0.18670542639193755
# Minibatch step 797/29916: mean batch inertia: 0.18664080810546874, ewa inertia: 0.18670499440604016
# Minibatch step 798/29916: mean batch inertia: 0.1863157501220703, ewa inertia: 0.18670239223178736
# Minibatch step 799/29916: mean batch inertia: 0.18796864318847656, ewa inertia: 0.18671085736736606
# Minibatch step 800/29916: mean batch inertia: 0.18755709838867188, ewa inertia: 0.18671651465428835
# Minibatch step 801/29916: mean batch inertia: 0.18694729614257813, ewa inertia: 0.1867180574737248
# Minibatch step 802/29916: mean batch inertia: 0.18573947143554687, ewa inertia: 0.1867115154344514
# Minibatch step 803/29916: mean batch inertia: 0.18717390441894532, ewa inertia: 0.186714606595349
# Minibatch step 804/29916: mean batch inertia: 0.1855093536376953, ewa inertia: 0.1867065492433373
# Minibatch step 805/29916: mean batch inertia: 0.18648178100585938, ewa inertia: 0.1867050466236599
# Minibatch step 806/29916: mean batch inertia: 0.18489443969726563, ewa inertia: 0.18669294236183823
# Minibatch step 807/29916: mean batch inertia: 0.18628652954101563, ewa inertia: 0.18669022541255498
# Minibatch step 808/29916: mean batch inertia: 0.18424842834472657, ewa inertia: 0.18667390152105015
# Minibatch step 809/29916: mean batch inertia: 0.18751309204101563, ewa inertia: 0.18667951167399047
# Minibatch step 810/29916: mean batch inertia: 0.18670608520507812, ewa inertia: 0.1866796893232489
# Minibatch step 811/29916: mean batch inertia: 0.18609866333007813, ewa inertia: 0.18667580505071907
# Minibatch step 812/29916: mean batch inertia: 0.18671141052246093, ewa inertia: 0.18667604308026925
# Minibatch step 813/29916: mean batch inertia: 0.18465484619140626, ewa inertia: 0.18666253098331478
# Minibatch step 814/29916: mean batch inertia: 0.1844857940673828, ewa inertia: 0.18664797907082445
# Minibatch step 815/29916: mean batch inertia: 0.18591053771972657, ewa inertia: 0.18664304913100058
# Minibatch step 816/29916: mean batch inertia: 0.186449462890625, ewa inertia: 0.18664175496907925
# Minibatch step 817/29916: mean batch inertia: 0.186375244140625, ewa inertia: 0.18663997329200793
# Minibatch step 818/29916: mean batch inertia: 0.18589228820800782, ewa inertia: 0.18663497487082387
# Minibatch step 819/29916: mean batch inertia: 0.18707347106933594, ewa inertia: 0.18663790630376892
# Minibatch step 820/29916: mean batch inertia: 0.1873236083984375, ewa inertia: 0.18664249035653294
# Minibatch step 821/29916: mean batch inertia: 0.18658558654785157, ewa inertia: 0.18664210994343006
# Minibatch step 822/29916: mean batch inertia: 0.1859586181640625, ewa inertia: 0.1866375406670566
# Minibatch step 823/29916: mean batch inertia: 0.18622564697265626, ewa inertia: 0.1866347870770603
# Minibatch step 824/29916: mean batch inertia: 0.1878070068359375, ewa inertia: 0.18664262359567022
# Minibatch step 825/29916: mean batch inertia: 0.18721502685546876, ewa inertia: 0.18664645022353912
# Minibatch step 826/29916: mean batch inertia: 0.18540383911132813, ewa inertia: 0.18663814312494945
# Minibatch step 827/29916: mean batch inertia: 0.18656320190429687, ewa inertia: 0.18663764212821582
# Minibatch step 828/29916: mean batch inertia: 0.1838424072265625, ewa inertia: 0.1866189554355884
# Minibatch step 829/29916: mean batch inertia: 0.1865327606201172, ewa inertia: 0.18661837920636992
# Minibatch step 830/29916: mean batch inertia: 0.18587258911132812, ewa inertia: 0.1866133934535581
# Minibatch step 831/29916: mean batch inertia: 0.18574172973632813, ewa inertia: 0.18660756621093574
# Minibatch step 832/29916: mean batch inertia: 0.18591961669921875, ewa inertia: 0.1866029671337487
# Minibatch step 833/29916: mean batch inertia: 0.18757546997070312, ewa inertia: 0.18660946850563076
# Minibatch step 834/29916: mean batch inertia: 0.18760678100585937, ewa inertia: 0.1866161357349696
# Minibatch step 835/29916: mean batch inertia: 0.18619305419921875, ewa inertia: 0.1866133073520633
# Minibatch step 836/29916: mean batch inertia: 0.1869311218261719, ewa inertia: 0.1866154320040511
# Minibatch step 837/29916: mean batch inertia: 0.1885625, ewa inertia: 0.18662844853484192
# Minibatch step 838/29916: mean batch inertia: 0.18543333435058593, ewa inertia: 0.18662045896251558
# Minibatch step 839/29916: mean batch inertia: 0.1873215789794922, ewa inertia: 0.1866251460871091
# Minibatch step 840/29916: mean batch inertia: 0.18553800964355469, ewa inertia: 0.1866178783671215
# Minibatch step 841/29916: mean batch inertia: 0.187489501953125, ewa inertia: 0.1866237053414587
# Minibatch step 842/29916: mean batch inertia: 0.1879609680175781, ewa inertia: 0.18663264520428594
# Converged (lack of improvement in inertia) at step 842/29916
# ✅ Codebook trained.

# %% [markdown]
# # Load dataset (train / val / test) với BoVW+HSV

# %%
def load_bovw_dataset(folder):
    """
    Load dataset với BoVW features.
    """
    X, y = [], []
    folder = Path(folder)

    for label, cls in enumerate(class_names):
        cls_dir = folder / cls
        img_files = []
        for ext in ("*.jpg", "*.jpeg", "*.png"):
            img_files.extend(cls_dir.glob(ext))

        print(f"[Load] {folder.name} - {cls}: {len(img_files)} images")

        for img_path in img_files:
            feat = image_to_bovw(img_path)
            X.append(feat)
            y.append(label)

    return np.array(X, dtype=np.float32), np.array(y, dtype=np.int32)


print("\n" + "="*50)
print("Loading datasets...")

X_train, y_train = load_bovw_dataset(train_dir)
X_val,   y_val   = load_bovw_dataset(val_dir)
X_test,  y_test  = load_bovw_dataset(test_dir)

print("\nDataset shapes:")
print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape,   y_val.shape)
print("Test :", X_test.shape,  y_test.shape)
# Out:
# ==================================================
# Loading datasets...
# [Load] train - daisy: 1231 images
# [Load] train - dandelion: 1046 images
# [Load] train - lily: 1132 images
# [Load] train - orchid: 1295 images
# [Load] train - rose: 1042 images
# [Load] train - sunflower: 1199 images
# [Load] train - tulip: 1124 images
# [Load] val - daisy: 352 images
# [Load] val - dandelion: 299 images
# [Load] val - lily: 324 images
# [Load] val - orchid: 370 images
# [Load] val - rose: 298 images
# [Load] val - sunflower: 342 images
# [Load] val - tulip: 321 images
# [Load] test - daisy: 176 images
# [Load] test - dandelion: 150 images
# [Load] test - lily: 162 images
# [Load] test - orchid: 186 images
# [Load] test - rose: 149 images
# [Load] test - sunflower: 172 images
# [Load] test - tulip: 161 images
#
# Dataset shapes:
# Train: (8069, 700) (8069,)
# Val  : (2306, 700) (2306,)
# Test : (1156, 700) (1156,)

# %% [markdown]
# # Chuẩn hoá và PCA

# %%
print("\n" + "="*50)
print("Standardizing features...")
print("="*50)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)
X_test_scaled  = scaler.transform(X_test)

print("Applying PCA...")
pca = PCA(n_components=192, random_state=42)
X_train_pca = pca.fit_transform(X_train_scaled)
X_val_pca   = pca.transform(X_val_scaled)
X_test_pca  = pca.transform(X_test_scaled)

print("Original dim:", X_train_scaled.shape[1])
print("After PCA   :", X_train_pca.shape[1])
# Out:
# ==================================================
# Standardizing features...
# ==================================================
# Applying PCA...
# Original dim: 700
# After PCA   : 192

# %% [markdown]
# # Train SVM

# %%
best_params = {"C": 10, "gamma": "scale", "kernel": "rbf"}

print("\n" + "="*50)
print("TRAINING SVM (BoVW only)")
print("="*50)
print(f"Using hyperparameters: {best_params}")

clf = SVC(
    C=best_params["C"], 
    gamma=best_params["gamma"], 
    kernel=best_params["kernel"], 
    random_state=42
)

# Train trên train
clf.fit(X_train_pca, y_train)

# Đánh giá trên validation
val_pred = clf.predict(X_val_pca)
best_val_acc = accuracy_score(y_val, val_pred)

print(f"\n✅ Model trained successfully")
print(f"Validation accuracy: {best_val_acc:.4f}")

# ============================================
# Train lại trên Train+Val với best params
# ============================================

print("\n" + "="*50)
print("Training final model on Train+Val...")
print("="*50)

# Gộp train và val
X_train_full = np.vstack([X_train, X_val])  
y_train_full = np.hstack([y_train, y_val])

# FIT LẠI scaler và PCA từ đầu
scaler = StandardScaler()
X_train_full_scaled = scaler.fit_transform(X_train_full)

pca = PCA(n_components=192, random_state=42)
X_train_full_pca = pca.fit_transform(X_train_full_scaled)

# Transform test
X_test_scaled = scaler.transform(X_test)  # X_test gốc
X_test_pca = pca.transform(X_test_scaled)

svm_final = SVC(
    C=best_params["C"], 
    gamma=best_params["gamma"], 
    kernel=best_params["kernel"], 
    random_state=42, 
    probability=True
)
svm_final.fit(X_train_full_pca, y_train_full)

print("✅ Final model trained.")
# Out:
# ==================================================
# TRAINING SVM (BoVW only)
# ==================================================
# Using hyperparameters: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#
# ✅ Model trained successfully
# Validation accuracy: 0.7832
#
# ==================================================
# Training final model on Train+Val...
# ==================================================
# ✅ Final model trained.

# %% [markdown]
# # Đánh giá

# %%
test_pred = svm_final.predict(X_test_pca)
test_acc = accuracy_score(y_test, test_pred)

print("\n" + "="*50)
print("ĐÁNH GIÁ TRÊN TEST SET")
print("="*50)
print("Test accuracy:", test_acc)
print("\nClassification report:")
print(classification_report(y_test, test_pred, target_names=class_names, digits=4))

# Confusion Matrix
cm = confusion_matrix(y_test, test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix - BoVW (RootSIFT) + SVM")
plt.show()
# Out:
# ==================================================
# ĐÁNH GIÁ TRÊN TEST SET
# ==================================================
# Test accuracy: 0.763840830449827
#
# Classification report:
#               precision    recall  f1-score   support
#
#        daisy     0.8931    0.8068    0.8478       176
#    dandelion     0.9161    0.8733    0.8942       150
#         lily     0.7186    0.7407    0.7295       162
#       orchid     0.6898    0.6935    0.6917       186
#         rose     0.6347    0.7114    0.6709       149
#    sunflower     0.7969    0.8895    0.8407       172
#        tulip     0.7234    0.6335    0.6755       161
#
#     accuracy                         0.7638      1156
#    macro avg     0.7675    0.7641    0.7643      1156
# weighted avg     0.7677    0.7638    0.7643      1156

# %%
# ============================================
# Hiển thị ảnh dự đoán đúng và sai
# ============================================

print("\n" + "="*50)
print("Finding correct and incorrect predictions...")
print("="*50)

# Lấy danh sách tất cả ảnh test
test_images = []
for label, cls in enumerate(class_names):
    cls_dir = test_dir / cls
    img_files = []
    for ext in ("*.jpg", "*.jpeg", "*.png"):
        img_files.extend(cls_dir.glob(ext))
    
    for img_path in img_files:
        test_images.append((img_path, label))

# Dự đoán và phân loại
correct_predictions = []
incorrect_predictions = []

for img_path, true_label in test_images:
    feats = image_to_bovw(img_path)
    feats = feats.reshape(1, -1)
    feats_scaled = scaler.transform(feats)
    feats_pca = pca.transform(feats_scaled)
    pred_label = svm_final.predict(feats_pca)[0]
    
    if pred_label == true_label:
        correct_predictions.append((img_path, true_label, pred_label))
    else:
        incorrect_predictions.append((img_path, true_label, pred_label))

print(f"Total correct: {len(correct_predictions)}")
print(f"Total incorrect: {len(incorrect_predictions)}")

# Hiển thị 3 ảnh dự đoán đúng
if len(correct_predictions) >= 3:
    print("\n" + "="*50)
    print("3 ẢNH DỰ ĐOÁN ĐÚNG")
    print("="*50)
    
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    np.random.seed(42)
    sample_correct = np.random.choice(len(correct_predictions), 3, replace=False)
    
    for idx, sample_idx in enumerate(sample_correct):
        img_path, true_label, pred_label = correct_predictions[sample_idx]
        img = cv2.imread(str(img_path))
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        axes[idx].imshow(img_rgb)
        axes[idx].set_title(f"True: {class_names[true_label]}\nPred: {class_names[pred_label]}", 
                           color='green', fontweight='bold')
        axes[idx].axis('off')
    
    plt.tight_layout()
    plt.show()

# Hiển thị 3 ảnh dự đoán sai
if len(incorrect_predictions) >= 3:
    print("\n" + "="*50)
    print("3 ẢNH DỰ ĐOÁN SAI")
    print("="*50)
    
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    np.random.seed(42)
    sample_incorrect = np.random.choice(len(incorrect_predictions), 3, replace=False)
    
    for idx, sample_idx in enumerate(sample_incorrect):
        img_path, true_label, pred_label = incorrect_predictions[sample_idx]
        img = cv2.imread(str(img_path))
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        axes[idx].imshow(img_rgb)
        axes[idx].set_title(f"True: {class_names[true_label]}\nPred: {class_names[pred_label]}", 
                           color='red', fontweight='bold')
        axes[idx].axis('off')
    
    plt.tight_layout()
    plt.show()
# Out:
# ==================================================
# Finding correct and incorrect predictions...
# ==================================================
# Total correct: 883
# Total incorrect: 273
#
# ==================================================
# 3 ẢNH DỰ ĐOÁN ĐÚNG
# ==================================================
# ==================================================
# 3 ẢNH DỰ ĐOÁN SAI
# ==================================================

# %% [markdown]
# # Lưu model

# %%
model_data = {
    "kmeans": kmeans,           # Để tạo BoVW từ SIFT
    "scaler": scaler,           # Để chuẩn hóa dữ liệu
    "pca": pca,                 # Để giảm chiều dữ liệu
    "model": svm_final,         # Model SVM cuối cùng
    "class_names": class_names, # Danh sách tên các loài hoa
    "K_value": K                # Số lượng cụm K (700)
}

filename = "bovw_only_svm.pkl"
with open(filename, "wb") as f:
    pickle.dump(model_data, f)

print("\n" + "="*50)
print(f"✅ Đã lưu xong file: {filename}")
print("="*50)
# Out:
# ==================================================
# ✅ Đã lưu xong file: bovw_only_svm.pkl
# ==================================================
